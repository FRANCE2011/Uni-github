# %% [markdown]
# ## ***Basic*** and ***safely*** managed ***sanitation*** services in different countries
# (servizi sanitari di base e gestiti in sicurezza nei diversi paesi)

# %% [markdown]
# ***

# %% [markdown]
#  Il lavoro consiste in un'analisi dettagliata di dati open source importati da una **fonte di Open Data** circa **fenomeni mondiali**
#
#    **FONTE:** WHO/OMS Global Health Data Repository: [https://apps.who.int/gho/data/node.home ]
#
#    From **6.2** SDG health and health-related targets **(Sanitation and hygiene)** in the section Water and sanitation, concatenated to the dataframe of the Health Equity Monitor section.

# %% [markdown]
# ### **OBIETTIVO ANALISI**

# %% [markdown]
# ***L'analisi ha l'obiettivo di individuare il fenomeno della stratificazione sociale e le disuguaglianze di salute dovute a diverse condizioni socio-economiche e culturali***

# %% [markdown]
# La classe sociale di appartenenza della popolazione è associata anche al concetto di aspettativa di vita.
# L'analisi vuole mettere in evidenza come le classi medie-alte hanno maggiori aspettative di vita, maggiore accesso alle risorse economiche , e come la differenza tra lavoro urbano e lavoro agricolo sia determinante per il tipo di stile di vita condotto e per la possibilità di ammalarsi o godere di una buona salute.
#
# Inoltre l'obiettivo è quello di mettere in relazione alcuni fattori socio-culturali con altri fattori economici, si evidenzia la correlazione tra livello di istruzione e aspettativa e stile di vita della persona.
#   Le classi sociali con maggiori risorse materiali (risorse economiche) avranno maggior accesso anche a quelle immateriali (servizi igenico-sanitari)

# %% [markdown]
# 1. **librerie da importare**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 2. dopo aver fatto il **download completo del data set come CSV table**, ho **salvato in locale** e attraverso il comando **head()** che permette la visualizzazione delle prime n righe del dataframe in esame, ho **visualizzato il file**. Si può specificare il numero di righe da visualizzare, esempio-head(20)-

# %%
df_sanitation = pd.read_csv(r"C:\Users\franc\Documents\UNIMI\COMPUTER SOCIETY\WSH_SANITATION_SAFELY_MANAGED,WSH_SANITATION_BASIC.csv")

# %%
df_sanitation.head(20)
# Out:
#              Unnamed: 0                                               2017  \
# 0                   NaN   Population using at least basic sanitation se...
# 1               Country                                              Total
# 2           Afghanistan                                                 43
# 3               Albania                                                 98
# 4               Algeria                                                 88
# 5               Andorra                                                100
# 6                Angola                                                 50
# 7   Antigua and Barbuda                                                 88
# 8             Argentina                                                NaN
# 9               Armenia                                                 94
# 10            Australia                                                100
# 11              Austria                                                100
# 12           Azerbaijan                                                 93
# 13              Bahamas                                                 95
# 14              Bahrain                                                100
# 15           Bangladesh                                                 48
# 16             Barbados                                                 97
# 17              Belarus                                                 98
# 18              Belgium                                                 99
# 19               Belize                                                 88
#
#                                                2017.1  \
# 0    Population using at least basic sanitation se...
# 1                                               Urban
# 2                                                  62
# 3                                                  98
# 4                                                  90
# 5                                                 100
# 6                                                  64
# 7                                                 NaN
# 8                                                  96
# 9                                                 100
# 10                                                NaN
# 11                                                100
# 12                                                 96
# 13                                                NaN
# 14                                                NaN
# 15                                                 51
# 16                                                NaN
# 17                                                 98
# 18                                                 99
# 19                                                 93
#
#                                                2017.2  \
# 0    Population using at least basic sanitation se...
# 1                                               Rural
# 2                                                  37
# 3                                                  97
# 4                                                  82
# 5                                                 100
# 6                                                  23
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  83
# 10                                                NaN
# 11                                                100
# 12                                                 88
# 13                                                NaN
# 14                                                NaN
# 15                                                 47
# 16                                                NaN
# 17                                                 96
# 18                                                 99
# 19                                                 83
#
#                                                2017.3  \
# 0    Population using safely managed sanitation se...
# 1                                               Total
# 2                                                 NaN
# 3                                                  40
# 4                                                  18
# 5                                                 100
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  48
# 10                                                 76
# 11                                                 97
# 12                                                NaN
# 13                                                NaN
# 14                                                 96
# 15                                                NaN
# 16                                                NaN
# 17                                                 81
# 18                                                 97
# 19                                                NaN
#
#                                                2017.4  \
# 0    Population using safely managed sanitation se...
# 1                                               Urban
# 2                                                 NaN
# 3                                                  40
# 4                                                  16
# 5                                                 100
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  45
# 10                                                NaN
# 11                                                100
# 12                                                 92
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                 82
# 18                                                NaN
# 19                                                NaN
#
#                                                2017.5  \
# 0    Population using safely managed sanitation se...
# 1                                               Rural
# 2                                                 NaN
# 3                                                  39
# 4                                                  21
# 5                                                 100
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                 92
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                 32
# 16                                                NaN
# 17                                                 76
# 18                                                NaN
# 19                                                NaN
#
#                                                  2016  \
# 0    Population using at least basic sanitation se...
# 1                                               Total
# 2                                                  42
# 3                                                  98
# 4                                                  88
# 5                                                 100
# 6                                                  49
# 7                                                  88
# 8                                                  94
# 9                                                  93
# 10                                                100
# 11                                                100
# 12                                                 92
# 13                                                 95
# 14                                                100
# 15                                                 47
# 16                                                 97
# 17                                                 98
# 18                                                 99
# 19                                                 88
#
#                                                2016.1  \
# 0    Population using at least basic sanitation se...
# 1                                               Urban
# 2                                                  60
# 3                                                  98
# 4                                                  90
# 5                                                 100
# 6                                                  63
# 7                                                 NaN
# 8                                                  96
# 9                                                 100
# 10                                                NaN
# 11                                                100
# 12                                                 96
# 13                                                NaN
# 14                                                NaN
# 15                                                 50
# 16                                                NaN
# 17                                                 98
# 18                                                 99
# 19                                                 93
#
#                                                2016.2  ...  \
# 0    Population using at least basic sanitation se...  ...
# 1                                               Rural  ...
# 2                                                  36  ...
# 3                                                  97  ...
# 4                                                  82  ...
# 5                                                 100  ...
# 6                                                  22  ...
# 7                                                 NaN  ...
# 8                                                  77  ...
# 9                                                  83  ...
# 10                                                NaN  ...
# 11                                                100  ...
# 12                                                 88  ...
# 13                                                NaN  ...
# 14                                                NaN  ...
# 15                                                 45  ...
# 16                                                NaN  ...
# 17                                                 96  ...
# 18                                                 99  ...
# 19                                                 83  ...
#
#                                                2001.2  \
# 0    Population using at least basic sanitation se...
# 1                                               Rural
# 2                                                  22
# 3                                                  83
# 4                                                  73
# 5                                                 100
# 6                                                   8
# 7                                                 NaN
# 8                                                  69
# 9                                                  77
# 10                                                NaN
# 11                                                100
# 12                                                 55
# 13                                                NaN
# 14                                                NaN
# 15                                                 21
# 16                                                NaN
# 17                                                 96
# 18                                                 99
# 19                                                 80
#
#                                                2001.3  \
# 0    Population using safely managed sanitation se...
# 1                                               Total
# 2                                                 NaN
# 3                                                  38
# 4                                                  19
# 5                                                  22
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  47
# 10                                                 64
# 11                                                 97
# 12                                                NaN
# 13                                                NaN
# 14                                                 96
# 15                                                NaN
# 16                                                NaN
# 17                                                 90
# 18                                                 86
# 19                                                NaN
#
#                                                2001.4  \
# 0    Population using safely managed sanitation se...
# 1                                               Urban
# 2                                                 NaN
# 3                                                  40
# 4                                                  18
# 5                                                  22
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  45
# 10                                                NaN
# 11                                                100
# 12                                                 71
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                 88
# 18                                                NaN
# 19                                                NaN
#
#                                                2001.5  \
# 0    Population using safely managed sanitation se...
# 1                                               Rural
# 2                                                 NaN
# 3                                                  37
# 4                                                  19
# 5                                                  22
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                 92
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                 15
# 16                                                NaN
# 17                                                 94
# 18                                                NaN
# 19                                                NaN
#
#                                                  2000  \
# 0    Population using at least basic sanitation se...
# 1                                               Total
# 2                                                  24
# 3                                                  88
# 4                                                  84
# 5                                                 100
# 6                                                  28
# 7                                                  82
# 8                                                  87
# 9                                                  87
# 10                                                100
# 11                                                100
# 12                                                 63
# 13                                                 88
# 14                                                100
# 15                                                 26
# 16                                                 89
# 17                                                 92
# 18                                                 99
# 19                                                 82
#
#                                                2000.1  \
# 0    Population using at least basic sanitation se...
# 1                                               Urban
# 2                                                  30
# 3                                                  97
# 4                                                  91
# 5                                                 100
# 6                                                  48
# 7                                                 NaN
# 8                                                  89
# 9                                                  92
# 10                                                NaN
# 11                                                100
# 12                                                 73
# 13                                                NaN
# 14                                                NaN
# 15                                                 44
# 16                                                NaN
# 17                                                 90
# 18                                                 99
# 19                                                 85
#
#                                                2000.2  \
# 0    Population using at least basic sanitation se...
# 1                                               Rural
# 2                                                  22
# 3                                                  82
# 4                                                  72
# 5                                                 100
# 6                                                   8
# 7                                                 NaN
# 8                                                  69
# 9                                                  77
# 10                                                NaN
# 11                                                100
# 12                                                 53
# 13                                                NaN
# 14                                                NaN
# 15                                                 20
# 16                                                NaN
# 17                                                 96
# 18                                                 99
# 19                                                 80
#
#                                                2000.3  \
# 0    Population using safely managed sanitation se...
# 1                                               Total
# 2                                                 NaN
# 3                                                  39
# 4                                                  19
# 5                                                  15
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  47
# 10                                                 64
# 11                                                 97
# 12                                                NaN
# 13                                                NaN
# 14                                                 96
# 15                                                NaN
# 16                                                NaN
# 17                                                 90
# 18                                                 86
# 19                                                NaN
#
#                                                2000.4  \
# 0    Population using safely managed sanitation se...
# 1                                               Urban
# 2                                                 NaN
# 3                                                  40
# 4                                                  18
# 5                                                  15
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  45
# 10                                                NaN
# 11                                                100
# 12                                                 70
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                 88
# 18                                                NaN
# 19                                                NaN
#
#                                                2000.5
# 0    Population using safely managed sanitation se...
# 1                                               Rural
# 2                                                 NaN
# 3                                                  38
# 4                                                  19
# 5                                                  15
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                 92
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                 14
# 16                                                NaN
# 17                                                 94
# 18                                                NaN
# 19                                                NaN
#
# [20 rows x 109 columns]

# %% [markdown]
# Si tratta di una tabella a doppia entrata che mette in rilievo negli anni, dal 2013 al 2017, la percentuale di popolazione che fa uso dei servizi sanitari a seconda delle due diversificate zone, urbane e rurali, dei vari paesi.

# %% [markdown]
# **variabili:**
# 1. la percentuale di popolazione che utilizza almeno servizi sanitari di base
# 2. la percentuale di popolazione che utilizza servizi sanitari gestiti in sicurezza
#
# 3. variabile anni (dal 2013 al 2017)
#
# 4. la variabile Country di tipo categoriale, è divisa in 3 sotto categorie: Total, Urban and Rural.

# %%
# vogliamo vedere che tipo di dati sono
type(df_sanitation)   # dataframe = dati in formato tabellare tipici della libraria Pandas
# Out:
# pandas.core.frame.DataFrame

# %%
 #avrei potuto utilizzare la print per vederle tutte ma graficamente è più efficace head()

# %% [markdown]
# ***

# %% [markdown]
# ### Alcune operazioni per ordinare il dataframe

# %%
new = df_sanitation.rename(columns={'Unnamed: 0' : 'Years', '2017.1' : '2017', '2017.2' : '2017'})  # ho provato a modificare l'anno 2017 con la funzione rename
new
# Out:
#                                   Years  \
# 0                                   NaN
# 1                               Country
# 2                           Afghanistan
# 3                               Albania
# 4                               Algeria
# ..                                  ...
# 191  Venezuela (Bolivarian Republic of)
# 192                            Viet Nam
# 193                               Yemen
# 194                              Zambia
# 195                            Zimbabwe
#
#                                                   2017  \
# 0     Population using at least basic sanitation se...
# 1                                                Total
# 2                                                   43
# 3                                                   98
# 4                                                   88
# ..                                                 ...
# 191                                                 94
# 192                                                 84
# 193                                                 59
# 194                                                 26
# 195                                                 36
#
#                                                   2017  \
# 0     Population using at least basic sanitation se...
# 1                                                Urban
# 2                                                   62
# 3                                                   98
# 4                                                   90
# ..                                                 ...
# 191                                                NaN
# 192                                                 94
# 193                                                 88
# 194                                                 36
# 195                                                 46
#
#                                                   2017  \
# 0     Population using at least basic sanitation se...
# 1                                                Rural
# 2                                                   37
# 3                                                   97
# 4                                                   82
# ..                                                 ...
# 191                                                NaN
# 192                                                 78
# 193                                                 43
# 194                                                 19
# 195                                                 31
#
#                                                 2017.3  \
# 0     Population using safely managed sanitation se...
# 1                                                Total
# 2                                                  NaN
# 3                                                   40
# 4                                                   18
# ..                                                 ...
# 191                                                 24
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                 2017.4  \
# 0     Population using safely managed sanitation se...
# 1                                                Urban
# 2                                                  NaN
# 3                                                   40
# 4                                                   16
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                 67
# 194                                                NaN
# 195                                                 16
#
#                                                 2017.5  \
# 0     Population using safely managed sanitation se...
# 1                                                Rural
# 2                                                  NaN
# 3                                                   39
# 4                                                   21
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                   2016  \
# 0     Population using at least basic sanitation se...
# 1                                                Total
# 2                                                   42
# 3                                                   98
# 4                                                   88
# ..                                                 ...
# 191                                                 94
# 192                                                 82
# 193                                                 59
# 194                                                 26
# 195                                                 37
#
#                                                 2016.1  \
# 0     Population using at least basic sanitation se...
# 1                                                Urban
# 2                                                   60
# 3                                                   98
# 4                                                   90
# ..                                                 ...
# 191                                                NaN
# 192                                                 94
# 193                                                 88
# 194                                                 36
# 195                                                 48
#
#                                                 2016.2  ...  \
# 0     Population using at least basic sanitation se...  ...
# 1                                                Rural  ...
# 2                                                   36  ...
# 3                                                   97  ...
# 4                                                   82  ...
# ..                                                 ...  ...
# 191                                                NaN  ...
# 192                                                 76  ...
# 193                                                 43  ...
# 194                                                 19  ...
# 195                                                 32  ...
#
#                                                 2001.2  \
# 0     Population using at least basic sanitation se...
# 1                                                Rural
# 2                                                   22
# 3                                                   83
# 4                                                   73
# ..                                                 ...
# 191                                                NaN
# 192                                                 45
# 193                                                 27
# 194                                                 12
# 195                                                 36
#
#                                                 2001.3  \
# 0     Population using safely managed sanitation se...
# 1                                                Total
# 2                                                  NaN
# 3                                                   38
# 4                                                   19
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                 2001.4  \
# 0     Population using safely managed sanitation se...
# 1                                                Urban
# 2                                                  NaN
# 3                                                   40
# 4                                                   18
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                 67
# 194                                                NaN
# 195                                                 23
#
#                                                 2001.5  \
# 0     Population using safely managed sanitation se...
# 1                                                Rural
# 2                                                  NaN
# 3                                                   37
# 4                                                   19
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                   2000  \
# 0     Population using at least basic sanitation se...
# 1                                                Total
# 2                                                   24
# 3                                                   88
# 4                                                   84
# ..                                                 ...
# 191                                                NaN
# 192                                                 52
# 193                                                 42
# 194                                                 24
# 195                                                 46
#
#                                                 2000.1  \
# 0     Population using at least basic sanitation se...
# 1                                                Urban
# 2                                                   30
# 3                                                   97
# 4                                                   91
# ..                                                 ...
# 191                                                NaN
# 192                                                 81
# 193                                                 86
# 194                                                 46
# 195                                                 65
#
#                                                 2000.2  \
# 0     Population using at least basic sanitation se...
# 1                                                Rural
# 2                                                   22
# 3                                                   82
# 4                                                   72
# ..                                                 ...
# 191                                                NaN
# 192                                                 43
# 193                                                 27
# 194                                                 12
# 195                                                 36
#
#                                                 2000.3  \
# 0     Population using safely managed sanitation se...
# 1                                                Total
# 2                                                  NaN
# 3                                                   39
# 4                                                   19
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                 2000.4  \
# 0     Population using safely managed sanitation se...
# 1                                                Urban
# 2                                                  NaN
# 3                                                   40
# 4                                                   18
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                 67
# 194                                                NaN
# 195                                                 23
#
#                                                 2000.5
# 0     Population using safely managed sanitation se...
# 1                                                Rural
# 2                                                  NaN
# 3                                                   38
# 4                                                   19
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
# [196 rows x 109 columns]

# %%
new = new.set_index('Years')   # indicizzo secondo Country
new
# Out:
#                                                                                  2017  \
# Years
# NaN                                  Population using at least basic sanitation se...
# Country                                                                         Total
# Afghanistan                                                                        43
# Albania                                                                            98
# Algeria                                                                            88
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                 94
# Viet Nam                                                                           84
# Yemen                                                                              59
# Zambia                                                                             26
# Zimbabwe                                                                           36
#
#                                                                                  2017  \
# Years
# NaN                                  Population using at least basic sanitation se...
# Country                                                                         Urban
# Afghanistan                                                                        62
# Albania                                                                            98
# Algeria                                                                            90
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                           94
# Yemen                                                                              88
# Zambia                                                                             36
# Zimbabwe                                                                           46
#
#                                                                                  2017  \
# Years
# NaN                                  Population using at least basic sanitation se...
# Country                                                                         Rural
# Afghanistan                                                                        37
# Albania                                                                            97
# Algeria                                                                            82
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                           78
# Yemen                                                                              43
# Zambia                                                                             19
# Zimbabwe                                                                           31
#
#                                                                                2017.3  \
# Years
# NaN                                  Population using safely managed sanitation se...
# Country                                                                         Total
# Afghanistan                                                                       NaN
# Albania                                                                            40
# Algeria                                                                            18
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                 24
# Viet Nam                                                                          NaN
# Yemen                                                                             NaN
# Zambia                                                                            NaN
# Zimbabwe                                                                          NaN
#
#                                                                                2017.4  \
# Years
# NaN                                  Population using safely managed sanitation se...
# Country                                                                         Urban
# Afghanistan                                                                       NaN
# Albania                                                                            40
# Algeria                                                                            16
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                          NaN
# Yemen                                                                              67
# Zambia                                                                            NaN
# Zimbabwe                                                                           16
#
#                                                                                2017.5  \
# Years
# NaN                                  Population using safely managed sanitation se...
# Country                                                                         Rural
# Afghanistan                                                                       NaN
# Albania                                                                            39
# Algeria                                                                            21
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                          NaN
# Yemen                                                                             NaN
# Zambia                                                                            NaN
# Zimbabwe                                                                          NaN
#
#                                                                                  2016  \
# Years
# NaN                                  Population using at least basic sanitation se...
# Country                                                                         Total
# Afghanistan                                                                        42
# Albania                                                                            98
# Algeria                                                                            88
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                 94
# Viet Nam                                                                           82
# Yemen                                                                              59
# Zambia                                                                             26
# Zimbabwe                                                                           37
#
#                                                                                2016.1  \
# Years
# NaN                                  Population using at least basic sanitation se...
# Country                                                                         Urban
# Afghanistan                                                                        60
# Albania                                                                            98
# Algeria                                                                            90
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                           94
# Yemen                                                                              88
# Zambia                                                                             36
# Zimbabwe                                                                           48
#
#                                                                                2016.2  \
# Years
# NaN                                  Population using at least basic sanitation se...
# Country                                                                         Rural
# Afghanistan                                                                        36
# Albania                                                                            97
# Algeria                                                                            82
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                           76
# Yemen                                                                              43
# Zambia                                                                             19
# Zimbabwe                                                                           32
#
#                                                                                2016.3  \
# Years
# NaN                                  Population using safely managed sanitation se...
# Country                                                                         Total
# Afghanistan                                                                       NaN
# Albania                                                                            40
# Algeria                                                                            18
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                 24
# Viet Nam                                                                          NaN
# Yemen                                                                             NaN
# Zambia                                                                            NaN
# Zimbabwe                                                                          NaN
#
#                                     ...  \
# Years                               ...
# NaN                                 ...
# Country                             ...
# Afghanistan                         ...
# Albania                             ...
# Algeria                             ...
# ...                                 ...
# Venezuela (Bolivarian Republic of)  ...
# Viet Nam                            ...
# Yemen                               ...
# Zambia                              ...
# Zimbabwe                            ...
#
#                                                                                2001.2  \
# Years
# NaN                                  Population using at least basic sanitation se...
# Country                                                                         Rural
# Afghanistan                                                                        22
# Albania                                                                            83
# Algeria                                                                            73
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                           45
# Yemen                                                                              27
# Zambia                                                                             12
# Zimbabwe                                                                           36
#
#                                                                                2001.3  \
# Years
# NaN                                  Population using safely managed sanitation se...
# Country                                                                         Total
# Afghanistan                                                                       NaN
# Albania                                                                            38
# Algeria                                                                            19
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                          NaN
# Yemen                                                                             NaN
# Zambia                                                                            NaN
# Zimbabwe                                                                          NaN
#
#                                                                                2001.4  \
# Years
# NaN                                  Population using safely managed sanitation se...
# Country                                                                         Urban
# Afghanistan                                                                       NaN
# Albania                                                                            40
# Algeria                                                                            18
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                          NaN
# Yemen                                                                              67
# Zambia                                                                            NaN
# Zimbabwe                                                                           23
#
#                                                                                2001.5  \
# Years
# NaN                                  Population using safely managed sanitation se...
# Country                                                                         Rural
# Afghanistan                                                                       NaN
# Albania                                                                            37
# Algeria                                                                            19
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                          NaN
# Yemen                                                                             NaN
# Zambia                                                                            NaN
# Zimbabwe                                                                          NaN
#
#                                                                                  2000  \
# Years
# NaN                                  Population using at least basic sanitation se...
# Country                                                                         Total
# Afghanistan                                                                        24
# Albania                                                                            88
# Algeria                                                                            84
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                           52
# Yemen                                                                              42
# Zambia                                                                             24
# Zimbabwe                                                                           46
#
#                                                                                2000.1  \
# Years
# NaN                                  Population using at least basic sanitation se...
# Country                                                                         Urban
# Afghanistan                                                                        30
# Albania                                                                            97
# Algeria                                                                            91
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                           81
# Yemen                                                                              86
# Zambia                                                                             46
# Zimbabwe                                                                           65
#
#                                                                                2000.2  \
# Years
# NaN                                  Population using at least basic sanitation se...
# Country                                                                         Rural
# Afghanistan                                                                        22
# Albania                                                                            82
# Algeria                                                                            72
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                           43
# Yemen                                                                              27
# Zambia                                                                             12
# Zimbabwe                                                                           36
#
#                                                                                2000.3  \
# Years
# NaN                                  Population using safely managed sanitation se...
# Country                                                                         Total
# Afghanistan                                                                       NaN
# Albania                                                                            39
# Algeria                                                                            19
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                          NaN
# Yemen                                                                             NaN
# Zambia                                                                            NaN
# Zimbabwe                                                                          NaN
#
#                                                                                2000.4  \
# Years
# NaN                                  Population using safely managed sanitation se...
# Country                                                                         Urban
# Afghanistan                                                                       NaN
# Albania                                                                            40
# Algeria                                                                            18
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                          NaN
# Yemen                                                                              67
# Zambia                                                                            NaN
# Zimbabwe                                                                           23
#
#                                                                                2000.5
# Years
# NaN                                  Population using safely managed sanitation se...
# Country                                                                         Rural
# Afghanistan                                                                       NaN
# Albania                                                                            38
# Algeria                                                                            19
# ...                                                                               ...
# Venezuela (Bolivarian Republic of)                                                NaN
# Viet Nam                                                                          NaN
# Yemen                                                                             NaN
# Zambia                                                                            NaN
# Zimbabwe                                                                          NaN
#
# [196 rows x 108 columns]

# %%
new['2000.5']   # esempio di selezione di colonna
# Out:
# Years
# NaN                                    Population using safely managed sanitation se...
# Country                                                                           Rural
# Afghanistan                                                                         NaN
# Albania                                                                              38
# Algeria                                                                              19
#                                                             ...
# Venezuela (Bolivarian Republic of)                                                  NaN
# Viet Nam                                                                            NaN
# Yemen                                                                               NaN
# Zambia                                                                              NaN
# Zimbabwe                                                                            NaN
# Name: 2000.5, Length: 196, dtype: object

# %%
new.transpose()  # utilizzo la funzione 'Trasposta' per una nuova visualizzazione del dataframe, composto da 38 Stati come colonne e 109 righe riferite gli anni
# Out:
# Years                                                 NaN Country Afghanistan  \
# 2017     Population using at least basic sanitation se...   Total          43
# 2017     Population using at least basic sanitation se...   Urban          62
# 2017     Population using at least basic sanitation se...   Rural          37
# 2017.3   Population using safely managed sanitation se...   Total         NaN
# 2017.4   Population using safely managed sanitation se...   Urban         NaN
# ...                                                   ...     ...         ...
# 2000.1   Population using at least basic sanitation se...   Urban          30
# 2000.2   Population using at least basic sanitation se...   Rural          22
# 2000.3   Population using safely managed sanitation se...   Total         NaN
# 2000.4   Population using safely managed sanitation se...   Urban         NaN
# 2000.5   Population using safely managed sanitation se...   Rural         NaN
#
# Years  Albania Algeria Andorra Angola Antigua and Barbuda Argentina Armenia  \
# 2017        98      88     100     50                  88       NaN      94
# 2017        98      90     100     64                 NaN        96     100
# 2017        97      82     100     23                 NaN       NaN      83
# 2017.3      40      18     100    NaN                 NaN       NaN      48
# 2017.4      40      16     100    NaN                 NaN       NaN      45
# ...        ...     ...     ...    ...                 ...       ...     ...
# 2000.1      97      91     100     48                 NaN        89      92
# 2000.2      82      72     100      8                 NaN        69      77
# 2000.3      39      19      15    NaN                 NaN       NaN      47
# 2000.4      40      18      15    NaN                 NaN       NaN      45
# 2000.5      38      19      15    NaN                 NaN       NaN     NaN
#
# Years   ... United Republic of Tanzania United States of America Uruguay  \
# 2017    ...                          30                      100      97
# 2017    ...                          43                      100      97
# 2017    ...                          24                      100      97
# 2017.3  ...                          25                       90     NaN
# 2017.4  ...                          31                       95     NaN
# ...     ...                         ...                      ...     ...
# 2000.1  ...                          11                      100      95
# 2000.2  ...                           3                      100      85
# 2000.3  ...                           4                       88     NaN
# 2000.4  ...                           9                       95     NaN
# 2000.5  ...                           2                      NaN     NaN
#
# Years  Uzbekistan Vanuatu Venezuela (Bolivarian Republic of) Viet Nam Yemen  \
# 2017          100      34                                 94       84    59
# 2017          100      48                                NaN       94    88
# 2017          100      29                                NaN       78    43
# 2017.3        NaN     NaN                                 24      NaN   NaN
# 2017.4        NaN     NaN                                NaN      NaN    67
# ...           ...     ...                                ...      ...   ...
# 2000.1         98      67                                NaN       81    86
# 2000.2         88      60                                NaN       43    27
# 2000.3        NaN     NaN                                NaN      NaN   NaN
# 2000.4        NaN     NaN                                NaN      NaN    67
# 2000.5        NaN     NaN                                NaN      NaN   NaN
#
# Years  Zambia Zimbabwe
# 2017       26       36
# 2017       36       46
# 2017       19       31
# 2017.3    NaN      NaN
# 2017.4    NaN       16
# ...       ...      ...
# 2000.1     46       65
# 2000.2     12       36
# 2000.3    NaN      NaN
# 2000.4    NaN       23
# 2000.5    NaN      NaN
#
# [108 rows x 196 columns]

# %% [markdown]
# #### Dalla visualizzazione di questa tabella è possibile osservare come in media, la percentuale più alta della popolazione delle varie nazioni, sia che utilizzino servizi sanitari di base, sia che utilizzino servizi gestiti in più sicurezza, appartiene alla classe urbana (e non a quella rurale).
# #### Da ciò si deduce come un primo fattore di incidenza, nonostante il minimo scostamento per alcune nazioni, sia la posizione geografica di residenza: la popolazione che vive in zone urbane ed è impiegata in lavori più salubri e redditizi avrà maggior accesso alla sanità.
#
# ###### -questi dati sono importanti al fine di spiegare questa correlazione.

# %% [markdown]
# ***

# %% [markdown]
# ##### Utilizzo la funzione stack per organizzare il mio dataframe in modo da poter eseguire più facilmente le operazioni

# %%
stacked = new.stack(level= -1, dropna= True)  # con la funzione stack trasformo l'indice in variabile o colonna. I valori associati a queste righe (non hanno un nome di colonna), vengono impilate
stacked
# Out:
# Years
# NaN       2017       Population using at least basic sanitation se...
#           2017       Population using at least basic sanitation se...
#           2017       Population using at least basic sanitation se...
#           2017.3     Population using safely managed sanitation se...
#           2017.4     Population using safely managed sanitation se...
#                                           ...
# Zimbabwe  2001.4                                                   23
#           2000                                                     46
#           2000.1                                                   65
#           2000.2                                                   36
#           2000.4                                                   23
# Length: 13239, dtype: object

# %%
# in questo modo per fare delle operazioni dovrò accedere alla selezione tramite la variabile Country

# %%
stacked.loc[['Albania', 'Zambia']]  # esempio di selezione con funzione loc. Doppia parentesi quadra perchè sto specificando una lista
# Out:
# Years
# Albania  2017      98
#          2017      98
#          2017      97
#          2017.3    40
#          2017.4    40
#                    ..
# Zambia   2001.1    45
#          2001.2    12
#          2000      24
#          2000.1    46
#          2000.2    12
# Length: 162, dtype: object

# %% [markdown]
# #### Analizziamo che tipo di dati sono

# %% [markdown]
# ***

# %% [markdown]
# ### **MASCHERE BOOLEANE**

# %% [markdown]
# Creiamo due mask di valori booleani secondo le due condizioni (urban e rural)

# %%
# importazione librerie per la visualizzazione grafica 
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
seaborn.scatterplot(data= stacked, x='Years', y='Andorra', hue='3')   # il risultato del grafico è sbagliato, è da rifare
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-532-596290650d67> in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn; seaborn.set()
# ----> 5 seaborn.scatterplot(data= stacked, x='Years', y='Andorra', hue='3')   # il risultato del grafico è sbagliato, è da rifare
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1388                 legend="brief", ax=None, **kwargs):
#    1389
# -> 1390     p = _ScatterPlotter(
#    1391         x=x, y=y, hue=hue, style=style, size=size, data=data,
#    1392         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     883                  legend=None):
#     884
# --> 885         plot_data = self.establish_variables(
#     886             x, y, hue, size, style, units, data
#     887         )
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     135                 if isinstance(var, str):
#     136                     err = "Could not interpret input '{}'".format(var)
# --> 137                     raise ValueError(err)
#     138
#     139             # Extract variable names
#
# ValueError: Could not interpret input 'Years'

# %% [markdown]
# ### **ANALISI VALORI NULLI (NAN)**

# %% [markdown]
# Il linguaggio di programmazione Python che si sta utilizzando, introduce una serie di dati mancanti:
#
# **-NONE
# -NAN**

# %% [markdown]
# Visualizziamo e analizziamo nello specifico i valori nulli nel dataset
#
# funzione ***isnull*** genera una maschera booleana che indica i valori mancanti

# %%
stacked.isnull().any  # restituisce valore booleano
# sono presenti alcuni valori nulli in determinate righe, dunque nella nostra analisi possono esserci problemi dovuti a missing value
# Out:
# <bound method Series.any of Years
# NaN       2017      False
#           2017      False
#           2017      False
#           2017.3    False
#           2017.4    False
#                     ...
# Zimbabwe  2001.4    False
#           2000      False
#           2000.1    False
#           2000.2    False
#           2000.4    False
# Length: 13239, dtype: bool>

# %% [markdown]
# Oppure

# %% [markdown]
# ##### **Del processo di esportazione non si ha informazioni, durante tale operazione possono venire a mancare alcuni dati che si sono cancellati o persi**

# %% [markdown]
# E' opportuno ragionare sia sui dati mancanti autodescrittivi, che sono evidenti ed espliciti, sia sul fatto che il risultato finale dell'analisi possibilmente sarà influenzato dai dati mancanti.
#
# **NAN (not a number)** è il tipo di dato mancante introdotto da Python specifico per i numeri decimali, è trattato come floating point (virgola mobile), diverso da **NONE** (codifica generica per tutti i dati-object-)
#
# Non fare un'accurata analisi dei dati mancanti è un errore dal punto di vista metodologico

# %% [markdown]
# ***Quale conseguenze in presenza di NAN?***
#
# è possibile procedere in due modi:
#
# -sostituendo in modo esplicito Nan con 0 (np.nansum fa la somma interpretando NAN come 0), oppure con altri valori specificati (data.fillna(0));
#
# -eliminando il valore mancante (dropna( )).
#
# Cancellare l'intera riga o il 50% delle righe non porta ad avere efficaci risultati, perchè si eliminerebbero dati che per una variabile sono mancanti ma per altre no.

# %% [markdown]
# #### Dunque sarebbe opportuno filtrare tutte le righe che restituiscono il valore booleano FALSE in un'unica colonna.

# %%
stacked.dropna(inplace=True) # oppure visualizzazione finale del dataset eliminando le righe in cui sono contenuti valori NaN
stacked
# Out:
# Years
# NaN       2017       Population using at least basic sanitation se...
#           2017       Population using at least basic sanitation se...
#           2017       Population using at least basic sanitation se...
#           2017.3     Population using safely managed sanitation se...
#           2017.4     Population using safely managed sanitation se...
#                                           ...
# Zimbabwe  2001.4                                                   23
#           2000                                                     46
#           2000.1                                                   65
#           2000.2                                                   36
#           2000.4                                                   23
# Length: 13239, dtype: object

# %% [markdown]
# ***

# %% [markdown]
# #### Definire condizioni logiche selezionando colonne - funzione QUERY

# %% [markdown]
# ***

# %%
stacked[1]   # seleziono la prima colonna in stile dizionario
# Out:
# ' Population using at least basic sanitation services (%)'

# %%
stacked.values # tutti i valori del dataframe
# Out:
# array([' Population using at least basic sanitation services (%)',
#        ' Population using at least basic sanitation services (%)',
#        ' Population using at least basic sanitation services (%)', ...,
#        '65', '36', '23'], dtype=object)

# %%
stacked.describe()  # utilizzo un metodo conveniente attraverso la funzione 'Describe' che calcola aggregati comuni per ogni colonna e ritorna i risultati. Descrive ogni gruppo nei dati
# Out:
# count     13239
# unique      105
# top         100
# freq       1089
# dtype: object

# %%
stacked.max(axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-556-fb97e07bf758> in <module>
# ----> 1 stacked.max(axis = 1)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11212         if level is not None:
#   11213             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11214         return self._reduce(
#   11215             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11216         )
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3867
#    3868         if axis is not None:
# -> 3869             self._get_axis_number(axis)
#    3870
#    3871         if isinstance(delegate, Categorical):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     405             except KeyError:
#     406                 pass
# --> 407         raise ValueError(f"No axis named {axis} for object type {cls}")
#     408
#     409     @classmethod
#
# ValueError: No axis named 1 for object type <class 'pandas.core.series.Series'>

# %%
stacked.min(axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-557-e17f5cea25d4> in <module>
# ----> 1 stacked.min(axis = 1)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11212         if level is not None:
#   11213             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11214         return self._reduce(
#   11215             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11216         )
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3867
#    3868         if axis is not None:
# -> 3869             self._get_axis_number(axis)
#    3870
#    3871         if isinstance(delegate, Categorical):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     405             except KeyError:
#     406                 pass
# --> 407         raise ValueError(f"No axis named {axis} for object type {cls}")
#     408
#     409     @classmethod
#
# ValueError: No axis named 1 for object type <class 'pandas.core.series.Series'>

# %% [markdown]
# ***

# %% [markdown]
# ### **CONCATENAZIONE DI DATAFRAME**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\franc\Documents\UNIMI\COMPUTER SOCIETY\LIFEEX.csv")  # importo un altro dataframe 
df
# Out:
#                Unnamed: 0 Unnamed: 1 Life expectancy at birth (years)  \
# 0              WHO region       Year                       Both sexes
# 1                  Global       2016                             72.0
# 2                  Global       2015                             71.7
# 3                  Global       2010                             70.1
# 4                  Global       2005                             68.2
# 5                  Global       2000                             66.5
# 6                  Africa       2016                             61.2
# 7                  Africa       2015                             60.7
# 8                  Africa       2010                             57.6
# 9                  Africa       2005                             53.4
# 10                 Africa       2000                             50.8
# 11               Americas       2016                             76.8
# 12               Americas       2015                             76.6
# 13               Americas       2010                             75.3
# 14               Americas       2005                             74.9
# 15               Americas       2000                             73.6
# 16        South-East Asia       2016                             69.5
# 17        South-East Asia       2015                             69.2
# 18        South-East Asia       2010                             67.4
# 19        South-East Asia       2005                             65.4
# 20        South-East Asia       2000                             63.5
# 21                 Europe       2016                             77.5
# 22                 Europe       2015                             77.2
# 23                 Europe       2010                             75.7
# 24                 Europe       2005                             73.5
# 25                 Europe       2000                             72.5
# 26  Eastern Mediterranean       2016                             69.1
# 27  Eastern Mediterranean       2015                             68.8
# 28  Eastern Mediterranean       2010                             68.1
# 29  Eastern Mediterranean       2005                             66.2
# 30  Eastern Mediterranean       2000                             65.5
# 31        Western Pacific       2016                             76.9
# 32        Western Pacific       2015                             76.7
# 33        Western Pacific       2010                             75.8
# 34        Western Pacific       2005                             74.7
# 35        Western Pacific       2000                             72.8
#
#    Life expectancy at birth (years).1 Life expectancy at birth (years).2  \
# 0                                Male                             Female
# 1                                69.8                               74.2
# 2                                69.5                               73.9
# 3                                68.0                               72.3
# 4                                66.1                               70.3
# 5                                64.4                               68.7
# 6                                59.6                               62.7
# 7                                59.1                               62.2
# 8                                56.4                               58.8
# 9                                52.3                               54.4
# 10                               49.6                               52.1
# 11                               73.8                               79.8
# 12                               73.7                               79.6
# 13                               72.3                               78.4
# 14                               71.9                               77.9
# 15                               70.4                               76.8
# 16                               67.9                               71.3
# 17                               67.6                               70.9
# 18                               66.1                               68.7
# 19                               64.4                               66.4
# 20                               62.5                               64.4
# 21                               74.2                               80.8
# 22                               73.8                               80.5
# 23                               72.0                               79.3
# 24                               69.5                               77.6
# 25                               68.4                               76.7
# 26                               67.7                               70.7
# 27                               67.4                               70.4
# 28                               66.7                               69.5
# 29                               64.8                               67.8
# 30                               64.2                               66.9
# 31                               75.0                               78.9
# 32                               74.8                               78.8
# 33                               73.8                               77.9
# 34                               72.7                               76.8
# 35                               70.8                               75.0
#
#    Life expectancy at age 60 (years) Life expectancy at age 60 (years).1  \
# 0                         Both sexes                                Male
# 1                               20.5                                19.0
# 2                               20.4                                18.9
# 3                               19.9                                18.4
# 4                               19.3                                17.8
# 5                               18.8                                17.2
# 6                               16.6                                15.9
# 7                               16.6                                15.8
# 8                               16.1                                15.4
# 9                               15.4                                14.7
# 10                              15.0                                14.3
# 11                              22.7                                21.1
# 12                              22.6                                21.0
# 13                              22.1                                20.4
# 14                              21.5                                19.8
# 15                              20.9                                19.1
# 16                              18.2                                17.2
# 17                              18.1                                17.1
# 18                              17.6                                16.7
# 19                              17.0                                16.2
# 20                              16.7                                15.8
# 21                              22.3                                20.2
# 22                              22.1                                20.0
# 23                              21.4                                19.2
# 24                              20.3                                18.1
# 25                              19.7                                17.3
# 26                              18.2                                17.5
# 27                              18.1                                17.4
# 28                              18.0                                17.3
# 29                              17.6                                16.9
# 30                              17.5                                16.8
# 31                              21.0                                19.5
# 32                              20.9                                19.4
# 33                              20.5                                19.0
# 34                              20.1                                18.6
# 35                              19.3                                17.8
#
#    Life expectancy at age 60 (years).2  \
# 0                               Female
# 1                                 21.9
# 2                                 21.8
# 3                                 21.3
# 4                                 20.7
# 5                                 20.2
# 6                                 17.3
# 7                                 17.3
# 8                                 16.7
# 9                                 16.1
# 10                                15.6
# 11                                24.3
# 12                                24.1
# 13                                23.6
# 14                                23.1
# 15                                22.5
# 16                                19.1
# 17                                19.0
# 18                                18.4
# 19                                17.8
# 20                                17.5
# 21                                24.1
# 22                                23.9
# 23                                23.2
# 24                                22.3
# 25                                21.6
# 26                                19.0
# 27                                18.8
# 28                                18.7
# 29                                18.4
# 30                                18.2
# 31                                22.5
# 32                                22.4
# 33                                22.1
# 34                                21.6
# 35                                20.9
#
#    Healthy life expectancy (HALE) at birth (years)  \
# 0                                       Both sexes
# 1                                             63.3
# 2                                             63.0
# 3                                             61.7
# 4                                             60.0
# 5                                             58.5
# 6                                             53.8
# 7                                             53.3
# 8                                             50.4
# 9                                             46.7
# 10                                            44.4
# 11                                            67.5
# 12                                            67.4
# 13                                            66.3
# 14                                            66.0
# 15                                            64.9
# 16                                            60.4
# 17                                            60.0
# 18                                            58.5
# 19                                            56.6
# 20                                            54.8
# 21                                            68.4
# 22                                            68.1
# 23                                            66.9
# 24                                            65.1
# 25                                            64.2
# 26                                            59.7
# 27                                            59.4
# 28                                            58.6
# 29                                            57.0
# 30                                            56.2
# 31                                            68.9
# 32                                            68.6
# 33                                            67.8
# 34                                            66.9
# 35                                            65.2
#
#    Healthy life expectancy (HALE) at birth (years).1  \
# 0                                               Male
# 1                                               62.0
# 2                                               61.7
# 3                                               60.4
# 4                                               58.7
# 5                                               57.2
# 6                                               52.6
# 7                                               52.1
# 8                                               49.6
# 9                                               46.0
# 10                                              43.5
# 11                                              65.5
# 12                                              65.3
# 13                                              64.1
# 14                                              63.8
# 15                                              62.6
# 16                                              59.5
# 17                                              59.2
# 18                                              57.9
# 19                                              56.3
# 20                                              54.5
# 21                                              66.1
# 22                                              65.7
# 23                                              64.3
# 24                                              62.2
# 25                                              61.2
# 26                                              59.1
# 27                                              58.8
# 28                                              58.1
# 29                                              56.4
# 30                                              55.8
# 31                                              67.7
# 32                                              67.5
# 33                                              66.7
# 34                                              65.7
# 35                                              64.0
#
#    Healthy life expectancy (HALE) at birth (years).2  \
# 0                                             Female
# 1                                               64.8
# 2                                               64.5
# 3                                               63.1
# 4                                               61.3
# 5                                               59.9
# 6                                               54.9
# 7                                               54.4
# 8                                               51.3
# 9                                               47.4
# 10                                              45.3
# 11                                              69.6
# 12                                              69.5
# 13                                              68.4
# 14                                              68.1
# 15                                              67.1
# 16                                              61.3
# 17                                              60.9
# 18                                              59.0
# 19                                              56.9
# 20                                              55.1
# 21                                              70.7
# 22                                              70.5
# 23                                              69.5
# 24                                              68.2
# 25                                              67.3
# 26                                              60.4
# 27                                              60.1
# 28                                              59.2
# 29                                              57.6
# 30                                              56.8
# 31                                              70.0
# 32                                              69.8
# 33                                              69.1
# 34                                              68.1
# 35                                              66.5
#
#    Healthy life expectancy (HALE) at age 60 (years)  \
# 0                                        Both sexes
# 1                                              15.8
# 2                                              15.7
# 3                                              15.3
# 4                                              14.8
# 5                                              14.3
# 6                                              12.5
# 7                                              12.4
# 8                                              12.0
# 9                                              11.4
# 10                                             11.0
# 11                                             17.6
# 12                                             17.5
# 13                                             17.0
# 14                                             16.6
# 15                                             16.2
# 16                                             13.3
# 17                                             13.2
# 18                                             12.7
# 19                                             12.2
# 20                                             11.9
# 21                                             17.4
# 22                                             17.2
# 23                                             16.7
# 24                                             15.8
# 25                                             15.3
# 26                                             13.3
# 27                                             13.2
# 28                                             13.0
# 29                                             12.6
# 30                                             12.4
# 31                                             16.6
# 32                                             16.5
# 33                                             16.2
# 34                                             15.9
# 35                                             15.3
#
#    Healthy life expectancy (HALE) at age 60 (years).1  \
# 0                                                Male
# 1                                                14.8
# 2                                                14.7
# 3                                                14.3
# 4                                                13.7
# 5                                                13.2
# 6                                                12.0
# 7                                                11.8
# 8                                                11.5
# 9                                                10.9
# 10                                               10.5
# 11                                               16.4
# 12                                               16.2
# 13                                               15.8
# 14                                               15.3
# 15                                               14.8
# 16                                               12.7
# 17                                               12.6
# 18                                               12.2
# 19                                               11.8
# 20                                               11.4
# 21                                               15.9
# 22                                               15.7
# 23                                               15.1
# 24                                               14.2
# 25                                               13.5
# 26                                               13.0
# 27                                               12.9
# 28                                               12.7
# 29                                               12.3
# 30                                               12.1
# 31                                               15.6
# 32                                               15.5
# 33                                               15.1
# 34                                               14.8
# 35                                               14.2
#
#    Healthy life expectancy (HALE) at age 60 (years).2
# 0                                              Female
# 1                                                16.8
# 2                                                16.6
# 3                                                16.2
# 4                                                15.8
# 5                                                15.4
# 6                                                13.1
# 7                                                13.0
# 8                                                12.4
# 9                                                11.8
# 10                                               11.4
# 11                                               18.7
# 12                                               18.6
# 13                                               18.2
# 14                                               17.8
# 15                                               17.4
# 16                                               13.9
# 17                                               13.7
# 18                                               13.2
# 19                                               12.7
# 20                                               12.4
# 21                                               18.7
# 22                                               18.5
# 23                                               18.0
# 24                                               17.3
# 25                                               16.7
# 26                                               13.6
# 27                                               13.5
# 28                                               13.3
# 29                                               12.9
# 30                                               12.7
# 31                                               17.6
# 32                                               17.5
# 33                                               17.3
# 34                                               16.9
# 35                                               16.3

# %% [markdown]
# * Per prima cosa faccio qualche operazione per ordinare il mio dataset

# %%
data = df.rename(columns={'Unnamed: 0' : 'Continent', 'Unnamed: 1' : 'Year'})  # per rinominare il nome della prima e seconda colonna, passo i vecchi e nuovi nomi come dizionario
# ho utilizzato la funzione rename
data
# Out:
#                 Continent   Year Life expectancy at birth (years)  \
# 0              WHO region   Year                       Both sexes
# 1                  Global   2016                             72.0
# 2                  Global   2015                             71.7
# 3                  Global   2010                             70.1
# 4                  Global   2005                             68.2
# 5                  Global   2000                             66.5
# 6                  Africa   2016                             61.2
# 7                  Africa   2015                             60.7
# 8                  Africa   2010                             57.6
# 9                  Africa   2005                             53.4
# 10                 Africa   2000                             50.8
# 11               Americas   2016                             76.8
# 12               Americas   2015                             76.6
# 13               Americas   2010                             75.3
# 14               Americas   2005                             74.9
# 15               Americas   2000                             73.6
# 16        South-East Asia   2016                             69.5
# 17        South-East Asia   2015                             69.2
# 18        South-East Asia   2010                             67.4
# 19        South-East Asia   2005                             65.4
# 20        South-East Asia   2000                             63.5
# 21                 Europe   2016                             77.5
# 22                 Europe   2015                             77.2
# 23                 Europe   2010                             75.7
# 24                 Europe   2005                             73.5
# 25                 Europe   2000                             72.5
# 26  Eastern Mediterranean   2016                             69.1
# 27  Eastern Mediterranean   2015                             68.8
# 28  Eastern Mediterranean   2010                             68.1
# 29  Eastern Mediterranean   2005                             66.2
# 30  Eastern Mediterranean   2000                             65.5
# 31        Western Pacific   2016                             76.9
# 32        Western Pacific   2015                             76.7
# 33        Western Pacific   2010                             75.8
# 34        Western Pacific   2005                             74.7
# 35        Western Pacific   2000                             72.8
#
#    Life expectancy at birth (years).1 Life expectancy at birth (years).2  \
# 0                                Male                             Female
# 1                                69.8                               74.2
# 2                                69.5                               73.9
# 3                                68.0                               72.3
# 4                                66.1                               70.3
# 5                                64.4                               68.7
# 6                                59.6                               62.7
# 7                                59.1                               62.2
# 8                                56.4                               58.8
# 9                                52.3                               54.4
# 10                               49.6                               52.1
# 11                               73.8                               79.8
# 12                               73.7                               79.6
# 13                               72.3                               78.4
# 14                               71.9                               77.9
# 15                               70.4                               76.8
# 16                               67.9                               71.3
# 17                               67.6                               70.9
# 18                               66.1                               68.7
# 19                               64.4                               66.4
# 20                               62.5                               64.4
# 21                               74.2                               80.8
# 22                               73.8                               80.5
# 23                               72.0                               79.3
# 24                               69.5                               77.6
# 25                               68.4                               76.7
# 26                               67.7                               70.7
# 27                               67.4                               70.4
# 28                               66.7                               69.5
# 29                               64.8                               67.8
# 30                               64.2                               66.9
# 31                               75.0                               78.9
# 32                               74.8                               78.8
# 33                               73.8                               77.9
# 34                               72.7                               76.8
# 35                               70.8                               75.0
#
#    Life expectancy at age 60 (years) Life expectancy at age 60 (years).1  \
# 0                         Both sexes                                Male
# 1                               20.5                                19.0
# 2                               20.4                                18.9
# 3                               19.9                                18.4
# 4                               19.3                                17.8
# 5                               18.8                                17.2
# 6                               16.6                                15.9
# 7                               16.6                                15.8
# 8                               16.1                                15.4
# 9                               15.4                                14.7
# 10                              15.0                                14.3
# 11                              22.7                                21.1
# 12                              22.6                                21.0
# 13                              22.1                                20.4
# 14                              21.5                                19.8
# 15                              20.9                                19.1
# 16                              18.2                                17.2
# 17                              18.1                                17.1
# 18                              17.6                                16.7
# 19                              17.0                                16.2
# 20                              16.7                                15.8
# 21                              22.3                                20.2
# 22                              22.1                                20.0
# 23                              21.4                                19.2
# 24                              20.3                                18.1
# 25                              19.7                                17.3
# 26                              18.2                                17.5
# 27                              18.1                                17.4
# 28                              18.0                                17.3
# 29                              17.6                                16.9
# 30                              17.5                                16.8
# 31                              21.0                                19.5
# 32                              20.9                                19.4
# 33                              20.5                                19.0
# 34                              20.1                                18.6
# 35                              19.3                                17.8
#
#    Life expectancy at age 60 (years).2  \
# 0                               Female
# 1                                 21.9
# 2                                 21.8
# 3                                 21.3
# 4                                 20.7
# 5                                 20.2
# 6                                 17.3
# 7                                 17.3
# 8                                 16.7
# 9                                 16.1
# 10                                15.6
# 11                                24.3
# 12                                24.1
# 13                                23.6
# 14                                23.1
# 15                                22.5
# 16                                19.1
# 17                                19.0
# 18                                18.4
# 19                                17.8
# 20                                17.5
# 21                                24.1
# 22                                23.9
# 23                                23.2
# 24                                22.3
# 25                                21.6
# 26                                19.0
# 27                                18.8
# 28                                18.7
# 29                                18.4
# 30                                18.2
# 31                                22.5
# 32                                22.4
# 33                                22.1
# 34                                21.6
# 35                                20.9
#
#    Healthy life expectancy (HALE) at birth (years)  \
# 0                                       Both sexes
# 1                                             63.3
# 2                                             63.0
# 3                                             61.7
# 4                                             60.0
# 5                                             58.5
# 6                                             53.8
# 7                                             53.3
# 8                                             50.4
# 9                                             46.7
# 10                                            44.4
# 11                                            67.5
# 12                                            67.4
# 13                                            66.3
# 14                                            66.0
# 15                                            64.9
# 16                                            60.4
# 17                                            60.0
# 18                                            58.5
# 19                                            56.6
# 20                                            54.8
# 21                                            68.4
# 22                                            68.1
# 23                                            66.9
# 24                                            65.1
# 25                                            64.2
# 26                                            59.7
# 27                                            59.4
# 28                                            58.6
# 29                                            57.0
# 30                                            56.2
# 31                                            68.9
# 32                                            68.6
# 33                                            67.8
# 34                                            66.9
# 35                                            65.2
#
#    Healthy life expectancy (HALE) at birth (years).1  \
# 0                                               Male
# 1                                               62.0
# 2                                               61.7
# 3                                               60.4
# 4                                               58.7
# 5                                               57.2
# 6                                               52.6
# 7                                               52.1
# 8                                               49.6
# 9                                               46.0
# 10                                              43.5
# 11                                              65.5
# 12                                              65.3
# 13                                              64.1
# 14                                              63.8
# 15                                              62.6
# 16                                              59.5
# 17                                              59.2
# 18                                              57.9
# 19                                              56.3
# 20                                              54.5
# 21                                              66.1
# 22                                              65.7
# 23                                              64.3
# 24                                              62.2
# 25                                              61.2
# 26                                              59.1
# 27                                              58.8
# 28                                              58.1
# 29                                              56.4
# 30                                              55.8
# 31                                              67.7
# 32                                              67.5
# 33                                              66.7
# 34                                              65.7
# 35                                              64.0
#
#    Healthy life expectancy (HALE) at birth (years).2  \
# 0                                             Female
# 1                                               64.8
# 2                                               64.5
# 3                                               63.1
# 4                                               61.3
# 5                                               59.9
# 6                                               54.9
# 7                                               54.4
# 8                                               51.3
# 9                                               47.4
# 10                                              45.3
# 11                                              69.6
# 12                                              69.5
# 13                                              68.4
# 14                                              68.1
# 15                                              67.1
# 16                                              61.3
# 17                                              60.9
# 18                                              59.0
# 19                                              56.9
# 20                                              55.1
# 21                                              70.7
# 22                                              70.5
# 23                                              69.5
# 24                                              68.2
# 25                                              67.3
# 26                                              60.4
# 27                                              60.1
# 28                                              59.2
# 29                                              57.6
# 30                                              56.8
# 31                                              70.0
# 32                                              69.8
# 33                                              69.1
# 34                                              68.1
# 35                                              66.5
#
#    Healthy life expectancy (HALE) at age 60 (years)  \
# 0                                        Both sexes
# 1                                              15.8
# 2                                              15.7
# 3                                              15.3
# 4                                              14.8
# 5                                              14.3
# 6                                              12.5
# 7                                              12.4
# 8                                              12.0
# 9                                              11.4
# 10                                             11.0
# 11                                             17.6
# 12                                             17.5
# 13                                             17.0
# 14                                             16.6
# 15                                             16.2
# 16                                             13.3
# 17                                             13.2
# 18                                             12.7
# 19                                             12.2
# 20                                             11.9
# 21                                             17.4
# 22                                             17.2
# 23                                             16.7
# 24                                             15.8
# 25                                             15.3
# 26                                             13.3
# 27                                             13.2
# 28                                             13.0
# 29                                             12.6
# 30                                             12.4
# 31                                             16.6
# 32                                             16.5
# 33                                             16.2
# 34                                             15.9
# 35                                             15.3
#
#    Healthy life expectancy (HALE) at age 60 (years).1  \
# 0                                                Male
# 1                                                14.8
# 2                                                14.7
# 3                                                14.3
# 4                                                13.7
# 5                                                13.2
# 6                                                12.0
# 7                                                11.8
# 8                                                11.5
# 9                                                10.9
# 10                                               10.5
# 11                                               16.4
# 12                                               16.2
# 13                                               15.8
# 14                                               15.3
# 15                                               14.8
# 16                                               12.7
# 17                                               12.6
# 18                                               12.2
# 19                                               11.8
# 20                                               11.4
# 21                                               15.9
# 22                                               15.7
# 23                                               15.1
# 24                                               14.2
# 25                                               13.5
# 26                                               13.0
# 27                                               12.9
# 28                                               12.7
# 29                                               12.3
# 30                                               12.1
# 31                                               15.6
# 32                                               15.5
# 33                                               15.1
# 34                                               14.8
# 35                                               14.2
#
#    Healthy life expectancy (HALE) at age 60 (years).2
# 0                                              Female
# 1                                                16.8
# 2                                                16.6
# 3                                                16.2
# 4                                                15.8
# 5                                                15.4
# 6                                                13.1
# 7                                                13.0
# 8                                                12.4
# 9                                                11.8
# 10                                               11.4
# 11                                               18.7
# 12                                               18.6
# 13                                               18.2
# 14                                               17.8
# 15                                               17.4
# 16                                               13.9
# 17                                               13.7
# 18                                               13.2
# 19                                               12.7
# 20                                               12.4
# 21                                               18.7
# 22                                               18.5
# 23                                               18.0
# 24                                               17.3
# 25                                               16.7
# 26                                               13.6
# 27                                               13.5
# 28                                               13.3
# 29                                               12.9
# 30                                               12.7
# 31                                               17.6
# 32                                               17.5
# 33                                               17.3
# 34                                               16.9
# 35                                               16.3

# %%
data.set_index('Continent')
# Out:
#                         Year Life expectancy at birth (years)  \
# Continent
# WHO region              Year                       Both sexes
# Global                  2016                             72.0
# Global                  2015                             71.7
# Global                  2010                             70.1
# Global                  2005                             68.2
# Global                  2000                             66.5
# Africa                  2016                             61.2
# Africa                  2015                             60.7
# Africa                  2010                             57.6
# Africa                  2005                             53.4
# Africa                  2000                             50.8
# Americas                2016                             76.8
# Americas                2015                             76.6
# Americas                2010                             75.3
# Americas                2005                             74.9
# Americas                2000                             73.6
# South-East Asia         2016                             69.5
# South-East Asia         2015                             69.2
# South-East Asia         2010                             67.4
# South-East Asia         2005                             65.4
# South-East Asia         2000                             63.5
# Europe                  2016                             77.5
# Europe                  2015                             77.2
# Europe                  2010                             75.7
# Europe                  2005                             73.5
# Europe                  2000                             72.5
# Eastern Mediterranean   2016                             69.1
# Eastern Mediterranean   2015                             68.8
# Eastern Mediterranean   2010                             68.1
# Eastern Mediterranean   2005                             66.2
# Eastern Mediterranean   2000                             65.5
# Western Pacific         2016                             76.9
# Western Pacific         2015                             76.7
# Western Pacific         2010                             75.8
# Western Pacific         2005                             74.7
# Western Pacific         2000                             72.8
#
#                       Life expectancy at birth (years).1  \
# Continent
# WHO region                                          Male
# Global                                              69.8
# Global                                              69.5
# Global                                              68.0
# Global                                              66.1
# Global                                              64.4
# Africa                                              59.6
# Africa                                              59.1
# Africa                                              56.4
# Africa                                              52.3
# Africa                                              49.6
# Americas                                            73.8
# Americas                                            73.7
# Americas                                            72.3
# Americas                                            71.9
# Americas                                            70.4
# South-East Asia                                     67.9
# South-East Asia                                     67.6
# South-East Asia                                     66.1
# South-East Asia                                     64.4
# South-East Asia                                     62.5
# Europe                                              74.2
# Europe                                              73.8
# Europe                                              72.0
# Europe                                              69.5
# Europe                                              68.4
# Eastern Mediterranean                               67.7
# Eastern Mediterranean                               67.4
# Eastern Mediterranean                               66.7
# Eastern Mediterranean                               64.8
# Eastern Mediterranean                               64.2
# Western Pacific                                     75.0
# Western Pacific                                     74.8
# Western Pacific                                     73.8
# Western Pacific                                     72.7
# Western Pacific                                     70.8
#
#                       Life expectancy at birth (years).2  \
# Continent
# WHO region                                        Female
# Global                                              74.2
# Global                                              73.9
# Global                                              72.3
# Global                                              70.3
# Global                                              68.7
# Africa                                              62.7
# Africa                                              62.2
# Africa                                              58.8
# Africa                                              54.4
# Africa                                              52.1
# Americas                                            79.8
# Americas                                            79.6
# Americas                                            78.4
# Americas                                            77.9
# Americas                                            76.8
# South-East Asia                                     71.3
# South-East Asia                                     70.9
# South-East Asia                                     68.7
# South-East Asia                                     66.4
# South-East Asia                                     64.4
# Europe                                              80.8
# Europe                                              80.5
# Europe                                              79.3
# Europe                                              77.6
# Europe                                              76.7
# Eastern Mediterranean                               70.7
# Eastern Mediterranean                               70.4
# Eastern Mediterranean                               69.5
# Eastern Mediterranean                               67.8
# Eastern Mediterranean                               66.9
# Western Pacific                                     78.9
# Western Pacific                                     78.8
# Western Pacific                                     77.9
# Western Pacific                                     76.8
# Western Pacific                                     75.0
#
#                       Life expectancy at age 60 (years)  \
# Continent
# WHO region                                   Both sexes
# Global                                             20.5
# Global                                             20.4
# Global                                             19.9
# Global                                             19.3
# Global                                             18.8
# Africa                                             16.6
# Africa                                             16.6
# Africa                                             16.1
# Africa                                             15.4
# Africa                                             15.0
# Americas                                           22.7
# Americas                                           22.6
# Americas                                           22.1
# Americas                                           21.5
# Americas                                           20.9
# South-East Asia                                    18.2
# South-East Asia                                    18.1
# South-East Asia                                    17.6
# South-East Asia                                    17.0
# South-East Asia                                    16.7
# Europe                                             22.3
# Europe                                             22.1
# Europe                                             21.4
# Europe                                             20.3
# Europe                                             19.7
# Eastern Mediterranean                              18.2
# Eastern Mediterranean                              18.1
# Eastern Mediterranean                              18.0
# Eastern Mediterranean                              17.6
# Eastern Mediterranean                              17.5
# Western Pacific                                    21.0
# Western Pacific                                    20.9
# Western Pacific                                    20.5
# Western Pacific                                    20.1
# Western Pacific                                    19.3
#
#                       Life expectancy at age 60 (years).1  \
# Continent
# WHO region                                           Male
# Global                                               19.0
# Global                                               18.9
# Global                                               18.4
# Global                                               17.8
# Global                                               17.2
# Africa                                               15.9
# Africa                                               15.8
# Africa                                               15.4
# Africa                                               14.7
# Africa                                               14.3
# Americas                                             21.1
# Americas                                             21.0
# Americas                                             20.4
# Americas                                             19.8
# Americas                                             19.1
# South-East Asia                                      17.2
# South-East Asia                                      17.1
# South-East Asia                                      16.7
# South-East Asia                                      16.2
# South-East Asia                                      15.8
# Europe                                               20.2
# Europe                                               20.0
# Europe                                               19.2
# Europe                                               18.1
# Europe                                               17.3
# Eastern Mediterranean                                17.5
# Eastern Mediterranean                                17.4
# Eastern Mediterranean                                17.3
# Eastern Mediterranean                                16.9
# Eastern Mediterranean                                16.8
# Western Pacific                                      19.5
# Western Pacific                                      19.4
# Western Pacific                                      19.0
# Western Pacific                                      18.6
# Western Pacific                                      17.8
#
#                       Life expectancy at age 60 (years).2  \
# Continent
# WHO region                                         Female
# Global                                               21.9
# Global                                               21.8
# Global                                               21.3
# Global                                               20.7
# Global                                               20.2
# Africa                                               17.3
# Africa                                               17.3
# Africa                                               16.7
# Africa                                               16.1
# Africa                                               15.6
# Americas                                             24.3
# Americas                                             24.1
# Americas                                             23.6
# Americas                                             23.1
# Americas                                             22.5
# South-East Asia                                      19.1
# South-East Asia                                      19.0
# South-East Asia                                      18.4
# South-East Asia                                      17.8
# South-East Asia                                      17.5
# Europe                                               24.1
# Europe                                               23.9
# Europe                                               23.2
# Europe                                               22.3
# Europe                                               21.6
# Eastern Mediterranean                                19.0
# Eastern Mediterranean                                18.8
# Eastern Mediterranean                                18.7
# Eastern Mediterranean                                18.4
# Eastern Mediterranean                                18.2
# Western Pacific                                      22.5
# Western Pacific                                      22.4
# Western Pacific                                      22.1
# Western Pacific                                      21.6
# Western Pacific                                      20.9
#
#                       Healthy life expectancy (HALE) at birth (years)  \
# Continent
# WHO region                                                 Both sexes
# Global                                                           63.3
# Global                                                           63.0
# Global                                                           61.7
# Global                                                           60.0
# Global                                                           58.5
# Africa                                                           53.8
# Africa                                                           53.3
# Africa                                                           50.4
# Africa                                                           46.7
# Africa                                                           44.4
# Americas                                                         67.5
# Americas                                                         67.4
# Americas                                                         66.3
# Americas                                                         66.0
# Americas                                                         64.9
# South-East Asia                                                  60.4
# South-East Asia                                                  60.0
# South-East Asia                                                  58.5
# South-East Asia                                                  56.6
# South-East Asia                                                  54.8
# Europe                                                           68.4
# Europe                                                           68.1
# Europe                                                           66.9
# Europe                                                           65.1
# Europe                                                           64.2
# Eastern Mediterranean                                            59.7
# Eastern Mediterranean                                            59.4
# Eastern Mediterranean                                            58.6
# Eastern Mediterranean                                            57.0
# Eastern Mediterranean                                            56.2
# Western Pacific                                                  68.9
# Western Pacific                                                  68.6
# Western Pacific                                                  67.8
# Western Pacific                                                  66.9
# Western Pacific                                                  65.2
#
#                       Healthy life expectancy (HALE) at birth (years).1  \
# Continent
# WHO region                                                         Male
# Global                                                             62.0
# Global                                                             61.7
# Global                                                             60.4
# Global                                                             58.7
# Global                                                             57.2
# Africa                                                             52.6
# Africa                                                             52.1
# Africa                                                             49.6
# Africa                                                             46.0
# Africa                                                             43.5
# Americas                                                           65.5
# Americas                                                           65.3
# Americas                                                           64.1
# Americas                                                           63.8
# Americas                                                           62.6
# South-East Asia                                                    59.5
# South-East Asia                                                    59.2
# South-East Asia                                                    57.9
# South-East Asia                                                    56.3
# South-East Asia                                                    54.5
# Europe                                                             66.1
# Europe                                                             65.7
# Europe                                                             64.3
# Europe                                                             62.2
# Europe                                                             61.2
# Eastern Mediterranean                                              59.1
# Eastern Mediterranean                                              58.8
# Eastern Mediterranean                                              58.1
# Eastern Mediterranean                                              56.4
# Eastern Mediterranean                                              55.8
# Western Pacific                                                    67.7
# Western Pacific                                                    67.5
# Western Pacific                                                    66.7
# Western Pacific                                                    65.7
# Western Pacific                                                    64.0
#
#                       Healthy life expectancy (HALE) at birth (years).2  \
# Continent
# WHO region                                                       Female
# Global                                                             64.8
# Global                                                             64.5
# Global                                                             63.1
# Global                                                             61.3
# Global                                                             59.9
# Africa                                                             54.9
# Africa                                                             54.4
# Africa                                                             51.3
# Africa                                                             47.4
# Africa                                                             45.3
# Americas                                                           69.6
# Americas                                                           69.5
# Americas                                                           68.4
# Americas                                                           68.1
# Americas                                                           67.1
# South-East Asia                                                    61.3
# South-East Asia                                                    60.9
# South-East Asia                                                    59.0
# South-East Asia                                                    56.9
# South-East Asia                                                    55.1
# Europe                                                             70.7
# Europe                                                             70.5
# Europe                                                             69.5
# Europe                                                             68.2
# Europe                                                             67.3
# Eastern Mediterranean                                              60.4
# Eastern Mediterranean                                              60.1
# Eastern Mediterranean                                              59.2
# Eastern Mediterranean                                              57.6
# Eastern Mediterranean                                              56.8
# Western Pacific                                                    70.0
# Western Pacific                                                    69.8
# Western Pacific                                                    69.1
# Western Pacific                                                    68.1
# Western Pacific                                                    66.5
#
#                       Healthy life expectancy (HALE) at age 60 (years)  \
# Continent
# WHO region                                                  Both sexes
# Global                                                            15.8
# Global                                                            15.7
# Global                                                            15.3
# Global                                                            14.8
# Global                                                            14.3
# Africa                                                            12.5
# Africa                                                            12.4
# Africa                                                            12.0
# Africa                                                            11.4
# Africa                                                            11.0
# Americas                                                          17.6
# Americas                                                          17.5
# Americas                                                          17.0
# Americas                                                          16.6
# Americas                                                          16.2
# South-East Asia                                                   13.3
# South-East Asia                                                   13.2
# South-East Asia                                                   12.7
# South-East Asia                                                   12.2
# South-East Asia                                                   11.9
# Europe                                                            17.4
# Europe                                                            17.2
# Europe                                                            16.7
# Europe                                                            15.8
# Europe                                                            15.3
# Eastern Mediterranean                                             13.3
# Eastern Mediterranean                                             13.2
# Eastern Mediterranean                                             13.0
# Eastern Mediterranean                                             12.6
# Eastern Mediterranean                                             12.4
# Western Pacific                                                   16.6
# Western Pacific                                                   16.5
# Western Pacific                                                   16.2
# Western Pacific                                                   15.9
# Western Pacific                                                   15.3
#
#                       Healthy life expectancy (HALE) at age 60 (years).1  \
# Continent
# WHO region                                                          Male
# Global                                                              14.8
# Global                                                              14.7
# Global                                                              14.3
# Global                                                              13.7
# Global                                                              13.2
# Africa                                                              12.0
# Africa                                                              11.8
# Africa                                                              11.5
# Africa                                                              10.9
# Africa                                                              10.5
# Americas                                                            16.4
# Americas                                                            16.2
# Americas                                                            15.8
# Americas                                                            15.3
# Americas                                                            14.8
# South-East Asia                                                     12.7
# South-East Asia                                                     12.6
# South-East Asia                                                     12.2
# South-East Asia                                                     11.8
# South-East Asia                                                     11.4
# Europe                                                              15.9
# Europe                                                              15.7
# Europe                                                              15.1
# Europe                                                              14.2
# Europe                                                              13.5
# Eastern Mediterranean                                               13.0
# Eastern Mediterranean                                               12.9
# Eastern Mediterranean                                               12.7
# Eastern Mediterranean                                               12.3
# Eastern Mediterranean                                               12.1
# Western Pacific                                                     15.6
# Western Pacific                                                     15.5
# Western Pacific                                                     15.1
# Western Pacific                                                     14.8
# Western Pacific                                                     14.2
#
#                       Healthy life expectancy (HALE) at age 60 (years).2
# Continent
# WHO region                                                        Female
# Global                                                              16.8
# Global                                                              16.6
# Global                                                              16.2
# Global                                                              15.8
# Global                                                              15.4
# Africa                                                              13.1
# Africa                                                              13.0
# Africa                                                              12.4
# Africa                                                              11.8
# Africa                                                              11.4
# Americas                                                            18.7
# Americas                                                            18.6
# Americas                                                            18.2
# Americas                                                            17.8
# Americas                                                            17.4
# South-East Asia                                                     13.9
# South-East Asia                                                     13.7
# South-East Asia                                                     13.2
# South-East Asia                                                     12.7
# South-East Asia                                                     12.4
# Europe                                                              18.7
# Europe                                                              18.5
# Europe                                                              18.0
# Europe                                                              17.3
# Europe                                                              16.7
# Eastern Mediterranean                                               13.6
# Eastern Mediterranean                                               13.5
# Eastern Mediterranean                                               13.3
# Eastern Mediterranean                                               12.9
# Eastern Mediterranean                                               12.7
# Western Pacific                                                     17.6
# Western Pacific                                                     17.5
# Western Pacific                                                     17.3
# Western Pacific                                                     16.9
# Western Pacific                                                     16.3

# %%
data.groupby(['Continent'])[['Life expectancy at birth (years)']].aggregate('max')
# Out:
#                       Life expectancy at birth (years)
# Continent
# Africa                                            61.2
# Americas                                          76.8
# Eastern Mediterranean                             69.1
# Europe                                            77.5
# Global                                            72.0
# South-East Asia                                   69.5
# WHO region                                  Both sexes
# Western Pacific                                   76.9

# %%
pd.concat([tabella, data], join = 'inner',  ignore_index = False, axis = 1)
# Out:
# Empty DataFrame
# Columns: [0, Continent, Year, Life expectancy at birth (years), Life expectancy at birth (years).1, Life expectancy at birth (years).2, Life expectancy at age 60 (years), Life expectancy at age 60 (years).1, Life expectancy at age 60 (years).2, Healthy life expectancy (HALE) at birth (years), Healthy life expectancy (HALE) at birth (years).1, Healthy life expectancy (HALE) at birth (years).2, Healthy life expectancy (HALE) at age 60 (years), Healthy life expectancy (HALE) at age 60 (years).1, Healthy life expectancy (HALE) at age 60 (years).2]
# Index: []
