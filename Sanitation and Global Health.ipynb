# %% [markdown]
# ## ***Basic*** and ***safely*** managed ***sanitation*** services in different countries
# (servizi sanitari di base e gestiti in sicurezza nei diversi paesi)

# %% [markdown]
# ***

# %% [markdown]
#  Il lavoro consiste in un'analisi dettagliata di dati open source importati da una **fonte di Open Data** circa **fenomeni mondiali**
#
#    **FONTE:** WHO/OMS Global Health Data Repository: [https://apps.who.int/gho/data/node.home ]
#
#    From **6.2** SDG health and health-related targets **(Sanitation and hygiene)** in the section Water and sanitation, concatenated to the dataframe of the Health Equity Monitor section.

# %% [markdown]
# ### **OBIETTIVO ANALISI**

# %% [markdown]
# ***L'analisi ha l'obiettivo di individuare il fenomeno della stratificazione sociale e le disuguaglianze di salute dovute a diverse condizioni socio-economiche e culturali***

# %% [markdown]
# La classe sociale di appartenenza della popolazione è associata anche al concetto di aspettativa di vita.
# L'analisi vuole mettere in evidenza come le classi medie-alte hanno maggiori aspettative di vita, maggiore accesso alle risorse economiche , e come la differenza tra lavoro urbano e lavoro agricolo sia determinante per il tipo di stile di vita condotto e per la possibilità di ammalarsi o godere di una buona salute.
#
# Inoltre l'obiettivo è quello di mettere in relazione alcuni fattori socio-culturali con altri fattori economici, si evidenzia la correlazione tra livello di istruzione e aspettativa e stile di vita della persona.
#   Le classi sociali con maggiori risorse materiali (risorse economiche) avranno maggior accesso anche a quelle immateriali (servizi igenico-sanitari)

# %% [markdown]
# 1. **librerie da importare**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 2. dopo aver fatto il **download completo del data set come CSV table**, ho **salvato in locale** e attraverso il comando **head()** che permette la visualizzazione delle prime n righe del dataframe in esame, ho **visualizzato il file**. Si può specificare il numero di righe da visualizzare, esempio-head(20)-

# %%
df_sanitation = pd.read_csv(r"C:\Users\franc\Documents\UNIMI\COMPUTER SOCIETY\WSH_SANITATION_SAFELY_MANAGED,WSH_SANITATION_BASIC.csv")

# %%
df_sanitation.head(20)
# Out:
#              Unnamed: 0                                               2017  \
# 0                   NaN   Population using at least basic sanitation se...
# 1               Country                                              Total
# 2           Afghanistan                                                 43
# 3               Albania                                                 98
# 4               Algeria                                                 88
# 5               Andorra                                                100
# 6                Angola                                                 50
# 7   Antigua and Barbuda                                                 88
# 8             Argentina                                                NaN
# 9               Armenia                                                 94
# 10            Australia                                                100
# 11              Austria                                                100
# 12           Azerbaijan                                                 93
# 13              Bahamas                                                 95
# 14              Bahrain                                                100
# 15           Bangladesh                                                 48
# 16             Barbados                                                 97
# 17              Belarus                                                 98
# 18              Belgium                                                 99
# 19               Belize                                                 88
#
#                                                2017.1  \
# 0    Population using at least basic sanitation se...
# 1                                               Urban
# 2                                                  62
# 3                                                  98
# 4                                                  90
# 5                                                 100
# 6                                                  64
# 7                                                 NaN
# 8                                                  96
# 9                                                 100
# 10                                                NaN
# 11                                                100
# 12                                                 96
# 13                                                NaN
# 14                                                NaN
# 15                                                 51
# 16                                                NaN
# 17                                                 98
# 18                                                 99
# 19                                                 93
#
#                                                2017.2  \
# 0    Population using at least basic sanitation se...
# 1                                               Rural
# 2                                                  37
# 3                                                  97
# 4                                                  82
# 5                                                 100
# 6                                                  23
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  83
# 10                                                NaN
# 11                                                100
# 12                                                 88
# 13                                                NaN
# 14                                                NaN
# 15                                                 47
# 16                                                NaN
# 17                                                 96
# 18                                                 99
# 19                                                 83
#
#                                                2017.3  \
# 0    Population using safely managed sanitation se...
# 1                                               Total
# 2                                                 NaN
# 3                                                  40
# 4                                                  18
# 5                                                 100
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  48
# 10                                                 76
# 11                                                 97
# 12                                                NaN
# 13                                                NaN
# 14                                                 96
# 15                                                NaN
# 16                                                NaN
# 17                                                 81
# 18                                                 97
# 19                                                NaN
#
#                                                2017.4  \
# 0    Population using safely managed sanitation se...
# 1                                               Urban
# 2                                                 NaN
# 3                                                  40
# 4                                                  16
# 5                                                 100
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  45
# 10                                                NaN
# 11                                                100
# 12                                                 92
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                 82
# 18                                                NaN
# 19                                                NaN
#
#                                                2017.5  \
# 0    Population using safely managed sanitation se...
# 1                                               Rural
# 2                                                 NaN
# 3                                                  39
# 4                                                  21
# 5                                                 100
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                 92
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                 32
# 16                                                NaN
# 17                                                 76
# 18                                                NaN
# 19                                                NaN
#
#                                                  2016  \
# 0    Population using at least basic sanitation se...
# 1                                               Total
# 2                                                  42
# 3                                                  98
# 4                                                  88
# 5                                                 100
# 6                                                  49
# 7                                                  88
# 8                                                  94
# 9                                                  93
# 10                                                100
# 11                                                100
# 12                                                 92
# 13                                                 95
# 14                                                100
# 15                                                 47
# 16                                                 97
# 17                                                 98
# 18                                                 99
# 19                                                 88
#
#                                                2016.1  \
# 0    Population using at least basic sanitation se...
# 1                                               Urban
# 2                                                  60
# 3                                                  98
# 4                                                  90
# 5                                                 100
# 6                                                  63
# 7                                                 NaN
# 8                                                  96
# 9                                                 100
# 10                                                NaN
# 11                                                100
# 12                                                 96
# 13                                                NaN
# 14                                                NaN
# 15                                                 50
# 16                                                NaN
# 17                                                 98
# 18                                                 99
# 19                                                 93
#
#                                                2016.2  ...  \
# 0    Population using at least basic sanitation se...  ...
# 1                                               Rural  ...
# 2                                                  36  ...
# 3                                                  97  ...
# 4                                                  82  ...
# 5                                                 100  ...
# 6                                                  22  ...
# 7                                                 NaN  ...
# 8                                                  77  ...
# 9                                                  83  ...
# 10                                                NaN  ...
# 11                                                100  ...
# 12                                                 88  ...
# 13                                                NaN  ...
# 14                                                NaN  ...
# 15                                                 45  ...
# 16                                                NaN  ...
# 17                                                 96  ...
# 18                                                 99  ...
# 19                                                 83  ...
#
#                                                2001.2  \
# 0    Population using at least basic sanitation se...
# 1                                               Rural
# 2                                                  22
# 3                                                  83
# 4                                                  73
# 5                                                 100
# 6                                                   8
# 7                                                 NaN
# 8                                                  69
# 9                                                  77
# 10                                                NaN
# 11                                                100
# 12                                                 55
# 13                                                NaN
# 14                                                NaN
# 15                                                 21
# 16                                                NaN
# 17                                                 96
# 18                                                 99
# 19                                                 80
#
#                                                2001.3  \
# 0    Population using safely managed sanitation se...
# 1                                               Total
# 2                                                 NaN
# 3                                                  38
# 4                                                  19
# 5                                                  22
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  47
# 10                                                 64
# 11                                                 97
# 12                                                NaN
# 13                                                NaN
# 14                                                 96
# 15                                                NaN
# 16                                                NaN
# 17                                                 90
# 18                                                 86
# 19                                                NaN
#
#                                                2001.4  \
# 0    Population using safely managed sanitation se...
# 1                                               Urban
# 2                                                 NaN
# 3                                                  40
# 4                                                  18
# 5                                                  22
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  45
# 10                                                NaN
# 11                                                100
# 12                                                 71
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                 88
# 18                                                NaN
# 19                                                NaN
#
#                                                2001.5  \
# 0    Population using safely managed sanitation se...
# 1                                               Rural
# 2                                                 NaN
# 3                                                  37
# 4                                                  19
# 5                                                  22
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                 92
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                 15
# 16                                                NaN
# 17                                                 94
# 18                                                NaN
# 19                                                NaN
#
#                                                  2000  \
# 0    Population using at least basic sanitation se...
# 1                                               Total
# 2                                                  24
# 3                                                  88
# 4                                                  84
# 5                                                 100
# 6                                                  28
# 7                                                  82
# 8                                                  87
# 9                                                  87
# 10                                                100
# 11                                                100
# 12                                                 63
# 13                                                 88
# 14                                                100
# 15                                                 26
# 16                                                 89
# 17                                                 92
# 18                                                 99
# 19                                                 82
#
#                                                2000.1  \
# 0    Population using at least basic sanitation se...
# 1                                               Urban
# 2                                                  30
# 3                                                  97
# 4                                                  91
# 5                                                 100
# 6                                                  48
# 7                                                 NaN
# 8                                                  89
# 9                                                  92
# 10                                                NaN
# 11                                                100
# 12                                                 73
# 13                                                NaN
# 14                                                NaN
# 15                                                 44
# 16                                                NaN
# 17                                                 90
# 18                                                 99
# 19                                                 85
#
#                                                2000.2  \
# 0    Population using at least basic sanitation se...
# 1                                               Rural
# 2                                                  22
# 3                                                  82
# 4                                                  72
# 5                                                 100
# 6                                                   8
# 7                                                 NaN
# 8                                                  69
# 9                                                  77
# 10                                                NaN
# 11                                                100
# 12                                                 53
# 13                                                NaN
# 14                                                NaN
# 15                                                 20
# 16                                                NaN
# 17                                                 96
# 18                                                 99
# 19                                                 80
#
#                                                2000.3  \
# 0    Population using safely managed sanitation se...
# 1                                               Total
# 2                                                 NaN
# 3                                                  39
# 4                                                  19
# 5                                                  15
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  47
# 10                                                 64
# 11                                                 97
# 12                                                NaN
# 13                                                NaN
# 14                                                 96
# 15                                                NaN
# 16                                                NaN
# 17                                                 90
# 18                                                 86
# 19                                                NaN
#
#                                                2000.4  \
# 0    Population using safely managed sanitation se...
# 1                                               Urban
# 2                                                 NaN
# 3                                                  40
# 4                                                  18
# 5                                                  15
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  45
# 10                                                NaN
# 11                                                100
# 12                                                 70
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                 88
# 18                                                NaN
# 19                                                NaN
#
#                                                2000.5
# 0    Population using safely managed sanitation se...
# 1                                               Rural
# 2                                                 NaN
# 3                                                  38
# 4                                                  19
# 5                                                  15
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                 92
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                 14
# 16                                                NaN
# 17                                                 94
# 18                                                NaN
# 19                                                NaN
#
# [20 rows x 109 columns]

# %% [markdown]
# Si tratta di una tabella a doppia entrata che mette in rilievo negli anni, dal 2000 al 2017, la percentuale di popolazione che fa uso dei servizi sanitari a seconda delle due diversificate zone, urbane e rurali, dei vari paesi.

# %% [markdown]
# **variabili:**
# 1. la percentuale di popolazione che utilizza almeno servizi sanitari di base
# 2. la percentuale di popolazione che utilizza servizi sanitari gestiti in sicurezza
#
# 3. variabile anni (dal 2000 al 2017)
#
# 4. la variabile Country di tipo categoriale, è divisa in 3 sotto categorie: Total, Urban and Rural.

# %%
# vogliamo vedere che tipo di dati sono
type(df_sanitation)   # dataframe = dati in formato tabellare tipici della libraria Pandas
# Out:
# pandas.core.frame.DataFrame

# %%
 #avrei potuto utilizzare la print per vederle tutte ma graficamente è più efficace head()

# %% [markdown]
# ***

# %% [markdown]
# ### Alcune operazioni per ordinare il dataframe

# %%
df_sanitation.rename(columns={'Unnamed: 0' : 'Country'})
# Out:
#                                 Country  \
# 0                                   NaN
# 1                               Country
# 2                           Afghanistan
# 3                               Albania
# 4                               Algeria
# ..                                  ...
# 191  Venezuela (Bolivarian Republic of)
# 192                            Viet Nam
# 193                               Yemen
# 194                              Zambia
# 195                            Zimbabwe
#
#                                                   2017  \
# 0     Population using at least basic sanitation se...
# 1                                                Total
# 2                                                   43
# 3                                                   98
# 4                                                   88
# ..                                                 ...
# 191                                                 94
# 192                                                 84
# 193                                                 59
# 194                                                 26
# 195                                                 36
#
#                                                 2017.1  \
# 0     Population using at least basic sanitation se...
# 1                                                Urban
# 2                                                   62
# 3                                                   98
# 4                                                   90
# ..                                                 ...
# 191                                                NaN
# 192                                                 94
# 193                                                 88
# 194                                                 36
# 195                                                 46
#
#                                                 2017.2  \
# 0     Population using at least basic sanitation se...
# 1                                                Rural
# 2                                                   37
# 3                                                   97
# 4                                                   82
# ..                                                 ...
# 191                                                NaN
# 192                                                 78
# 193                                                 43
# 194                                                 19
# 195                                                 31
#
#                                                 2017.3  \
# 0     Population using safely managed sanitation se...
# 1                                                Total
# 2                                                  NaN
# 3                                                   40
# 4                                                   18
# ..                                                 ...
# 191                                                 24
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                 2017.4  \
# 0     Population using safely managed sanitation se...
# 1                                                Urban
# 2                                                  NaN
# 3                                                   40
# 4                                                   16
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                 67
# 194                                                NaN
# 195                                                 16
#
#                                                 2017.5  \
# 0     Population using safely managed sanitation se...
# 1                                                Rural
# 2                                                  NaN
# 3                                                   39
# 4                                                   21
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                   2016  \
# 0     Population using at least basic sanitation se...
# 1                                                Total
# 2                                                   42
# 3                                                   98
# 4                                                   88
# ..                                                 ...
# 191                                                 94
# 192                                                 82
# 193                                                 59
# 194                                                 26
# 195                                                 37
#
#                                                 2016.1  \
# 0     Population using at least basic sanitation se...
# 1                                                Urban
# 2                                                   60
# 3                                                   98
# 4                                                   90
# ..                                                 ...
# 191                                                NaN
# 192                                                 94
# 193                                                 88
# 194                                                 36
# 195                                                 48
#
#                                                 2016.2  ...  \
# 0     Population using at least basic sanitation se...  ...
# 1                                                Rural  ...
# 2                                                   36  ...
# 3                                                   97  ...
# 4                                                   82  ...
# ..                                                 ...  ...
# 191                                                NaN  ...
# 192                                                 76  ...
# 193                                                 43  ...
# 194                                                 19  ...
# 195                                                 32  ...
#
#                                                 2001.2  \
# 0     Population using at least basic sanitation se...
# 1                                                Rural
# 2                                                   22
# 3                                                   83
# 4                                                   73
# ..                                                 ...
# 191                                                NaN
# 192                                                 45
# 193                                                 27
# 194                                                 12
# 195                                                 36
#
#                                                 2001.3  \
# 0     Population using safely managed sanitation se...
# 1                                                Total
# 2                                                  NaN
# 3                                                   38
# 4                                                   19
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                 2001.4  \
# 0     Population using safely managed sanitation se...
# 1                                                Urban
# 2                                                  NaN
# 3                                                   40
# 4                                                   18
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                 67
# 194                                                NaN
# 195                                                 23
#
#                                                 2001.5  \
# 0     Population using safely managed sanitation se...
# 1                                                Rural
# 2                                                  NaN
# 3                                                   37
# 4                                                   19
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                   2000  \
# 0     Population using at least basic sanitation se...
# 1                                                Total
# 2                                                   24
# 3                                                   88
# 4                                                   84
# ..                                                 ...
# 191                                                NaN
# 192                                                 52
# 193                                                 42
# 194                                                 24
# 195                                                 46
#
#                                                 2000.1  \
# 0     Population using at least basic sanitation se...
# 1                                                Urban
# 2                                                   30
# 3                                                   97
# 4                                                   91
# ..                                                 ...
# 191                                                NaN
# 192                                                 81
# 193                                                 86
# 194                                                 46
# 195                                                 65
#
#                                                 2000.2  \
# 0     Population using at least basic sanitation se...
# 1                                                Rural
# 2                                                   22
# 3                                                   82
# 4                                                   72
# ..                                                 ...
# 191                                                NaN
# 192                                                 43
# 193                                                 27
# 194                                                 12
# 195                                                 36
#
#                                                 2000.3  \
# 0     Population using safely managed sanitation se...
# 1                                                Total
# 2                                                  NaN
# 3                                                   39
# 4                                                   19
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                 2000.4  \
# 0     Population using safely managed sanitation se...
# 1                                                Urban
# 2                                                  NaN
# 3                                                   40
# 4                                                   18
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                 67
# 194                                                NaN
# 195                                                 23
#
#                                                 2000.5
# 0     Population using safely managed sanitation se...
# 1                                                Rural
# 2                                                  NaN
# 3                                                   38
# 4                                                   19
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
# [196 rows x 109 columns]

# %%
df_sanitation.sort_values(by="2017") # vogliamo ordinare il dataframe in base all'anno 2017 per osservare quali paesi usano maggiori servizi sanitari basici
# Out:
#                    Unnamed: 0  \
# 0                         NaN
# 1                     Country
# 36                      Chile
# 88                      Japan
# 93                     Kuwait
# ..                        ...
# 26          Brunei Darussalam
# 34   Central African Republic
# 52                   Dominica
# 58                    Eritrea
# 147     Saint Kitts and Nevis
#
#                                                   2017  \
# 0     Population using at least basic sanitation se...
# 1                                                Total
# 36                                                 100
# 88                                                 100
# 93                                                 100
# ..                                                 ...
# 26                                                 NaN
# 34                                                 NaN
# 52                                                 NaN
# 58                                                 NaN
# 147                                                NaN
#
#                                                 2017.1  \
# 0     Population using at least basic sanitation se...
# 1                                                Urban
# 36                                                 100
# 88                                                 NaN
# 93                                                 NaN
# ..                                                 ...
# 26                                                 NaN
# 34                                                 NaN
# 52                                                 NaN
# 58                                                 NaN
# 147                                                NaN
#
#                                                 2017.2  \
# 0     Population using at least basic sanitation se...
# 1                                                Rural
# 36                                                 100
# 88                                                 NaN
# 93                                                 NaN
# ..                                                 ...
# 26                                                 NaN
# 34                                                 NaN
# 52                                                 NaN
# 58                                                 NaN
# 147                                                NaN
#
#                                                 2017.3  \
# 0     Population using safely managed sanitation se...
# 1                                                Total
# 36                                                  77
# 88                                                  99
# 93                                                 100
# ..                                                 ...
# 26                                                 NaN
# 34                                                 NaN
# 52                                                 NaN
# 58                                                 NaN
# 147                                                NaN
#
#                                                 2017.4  \
# 0     Population using safely managed sanitation se...
# 1                                                Urban
# 36                                                  81
# 88                                                 NaN
# 93                                                 NaN
# ..                                                 ...
# 26                                                 NaN
# 34                                                 NaN
# 52                                                 NaN
# 58                                                 NaN
# 147                                                NaN
#
#                                                 2017.5  \
# 0     Population using safely managed sanitation se...
# 1                                                Rural
# 36                                                 NaN
# 88                                                 NaN
# 93                                                 NaN
# ..                                                 ...
# 26                                                 NaN
# 34                                                 NaN
# 52                                                 NaN
# 58                                                 NaN
# 147                                                NaN
#
#                                                   2016  \
# 0     Population using at least basic sanitation se...
# 1                                                Total
# 36                                                 100
# 88                                                 100
# 93                                                 100
# ..                                                 ...
# 26                                                 NaN
# 34                                                  25
# 52                                                 NaN
# 58                                                  12
# 147                                                NaN
#
#                                                 2016.1  \
# 0     Population using at least basic sanitation se...
# 1                                                Urban
# 36                                                 100
# 88                                                 NaN
# 93                                                 NaN
# ..                                                 ...
# 26                                                 NaN
# 34                                                  49
# 52                                                 NaN
# 58                                                  22
# 147                                                NaN
#
#                                                 2016.2  ...  \
# 0     Population using at least basic sanitation se...  ...
# 1                                                Rural  ...
# 36                                                 100  ...
# 88                                                 NaN  ...
# 93                                                 NaN  ...
# ..                                                 ...  ...
# 26                                                 NaN  ...
# 34                                                   9  ...
# 52                                                 NaN  ...
# 58                                                   6  ...
# 147                                                NaN  ...
#
#                                                 2001.2  \
# 0     Population using at least basic sanitation se...
# 1                                                Rural
# 36                                                  70
# 88                                                 NaN
# 93                                                 NaN
# ..                                                 ...
# 26                                                 NaN
# 34                                                   8
# 52                                                 NaN
# 58                                                   2
# 147                                                NaN
#
#                                                 2001.3  \
# 0     Population using safely managed sanitation se...
# 1                                                Total
# 36                                                  49
# 88                                                  98
# 93                                                 100
# ..                                                 ...
# 26                                                 NaN
# 34                                                 NaN
# 52                                                 NaN
# 58                                                 NaN
# 147                                                NaN
#
#                                                 2001.4  \
# 0     Population using safely managed sanitation se...
# 1                                                Urban
# 36                                                  47
# 88                                                 NaN
# 93                                                 NaN
# ..                                                 ...
# 26                                                 NaN
# 34                                                 NaN
# 52                                                 NaN
# 58                                                 NaN
# 147                                                NaN
#
#                                                 2001.5  \
# 0     Population using safely managed sanitation se...
# 1                                                Rural
# 36                                                 NaN
# 88                                                 NaN
# 93                                                 NaN
# ..                                                 ...
# 26                                                 NaN
# 34                                                 NaN
# 52                                                 NaN
# 58                                                 NaN
# 147                                                NaN
#
#                                                   2000  \
# 0     Population using at least basic sanitation se...
# 1                                                Total
# 36                                                  92
# 88                                                 100
# 93                                                 100
# ..                                                 ...
# 26                                                 NaN
# 34                                                  15
# 52                                                  64
# 58                                                   8
# 147                                                 85
#
#                                                 2000.1  \
# 0     Population using at least basic sanitation se...
# 1                                                Urban
# 36                                                  96
# 88                                                 NaN
# 93                                                 NaN
# ..                                                 ...
# 26                                                 NaN
# 34                                                  26
# 52                                                 NaN
# 58                                                  27
# 147                                                NaN
#
#                                                 2000.2  \
# 0     Population using at least basic sanitation se...
# 1                                                Rural
# 36                                                  68
# 88                                                 NaN
# 93                                                 NaN
# ..                                                 ...
# 26                                                 NaN
# 34                                                   8
# 52                                                 NaN
# 58                                                   1
# 147                                                NaN
#
#                                                 2000.3  \
# 0     Population using safely managed sanitation se...
# 1                                                Total
# 36                                                  48
# 88                                                  97
# 93                                                 100
# ..                                                 ...
# 26                                                 NaN
# 34                                                 NaN
# 52                                                 NaN
# 58                                                 NaN
# 147                                                NaN
#
#                                                 2000.4  \
# 0     Population using safely managed sanitation se...
# 1                                                Urban
# 36                                                  47
# 88                                                 NaN
# 93                                                 NaN
# ..                                                 ...
# 26                                                 NaN
# 34                                                 NaN
# 52                                                 NaN
# 58                                                 NaN
# 147                                                NaN
#
#                                                 2000.5
# 0     Population using safely managed sanitation se...
# 1                                                Rural
# 36                                                 NaN
# 88                                                 NaN
# 93                                                 NaN
# ..                                                 ...
# 26                                                 NaN
# 34                                                 NaN
# 52                                                 NaN
# 58                                                 NaN
# 147                                                NaN
#
# [196 rows x 109 columns]

# %%
# non capisco perchè il rename della colonna, dopo che eseguo un altro comando, non lo visualizza più ma ritorna al nome originale

# %% [markdown]
# ### **ANALISI VALORI NULLI (NAN)**

# %% [markdown]
# Il linguaggio di programmazione Python che si sta utilizzando, introduce una serie di dati mancanti:
#
# **-NONE
# -NAN**

# %% [markdown]
# ***

# %% [markdown]
# Visualizziamo e analizziamo nello specifico i valori nulli nel dataset
#
# funzione ***isnull*** genera una maschera booleana che indica i valori mancanti

# %%
df_sanitation.isnull().any  # restituisce valore booleano
# sono presenti alcuni valori nulli in determinate righe, dunque nella nostra analisi possono esserci problemi dovuti a missing value
# Out:
# <bound method DataFrame.any of      Unnamed: 0   2017  2017.1  2017.2  2017.3  2017.4  2017.5   2016  2016.1  \
# 0          True  False   False   False   False   False   False  False   False
# 1         False  False   False   False   False   False   False  False   False
# 2         False  False   False   False    True    True    True  False   False
# 3         False  False   False   False   False   False   False  False   False
# 4         False  False   False   False   False   False   False  False   False
# ..          ...    ...     ...     ...     ...     ...     ...    ...     ...
# 191       False  False    True    True   False    True    True  False    True
# 192       False  False   False   False    True    True    True  False   False
# 193       False  False   False   False    True   False    True  False   False
# 194       False  False   False   False    True    True    True  False   False
# 195       False  False   False   False    True   False    True  False   False
#
#      2016.2  ...  2001.2  2001.3  2001.4  2001.5   2000  2000.1  2000.2  \
# 0     False  ...   False   False   False   False  False   False   False
# 1     False  ...   False   False   False   False  False   False   False
# 2     False  ...   False    True    True    True  False   False   False
# 3     False  ...   False   False   False   False  False   False   False
# 4     False  ...   False   False   False   False  False   False   False
# ..      ...  ...     ...     ...     ...     ...    ...     ...     ...
# 191    True  ...    True    True    True    True   True    True    True
# 192   False  ...   False    True    True    True  False   False   False
# 193   False  ...   False    True   False    True  False   False   False
# 194   False  ...   False    True    True    True  False   False   False
# 195   False  ...   False    True   False    True  False   False   False
#
#      2000.3  2000.4  2000.5
# 0     False   False   False
# 1     False   False   False
# 2      True    True    True
# 3     False   False   False
# 4     False   False   False
# ..      ...     ...     ...
# 191    True    True    True
# 192    True    True    True
# 193    True   False    True
# 194    True    True    True
# 195    True   False    True
#
# [196 rows x 109 columns]>

# %%
df_sanitation.isna() # utilizzo funzione isna() che mi restituisce True per ogni valore Nan, specifica quali celle nel nostro dataset sono mancanti, oppure il comando opposto notna()
# Out:
#      Unnamed: 0   2017  2017.1  2017.2  2017.3  2017.4  2017.5   2016  2016.1  \
# 0          True  False   False   False   False   False   False  False   False
# 1         False  False   False   False   False   False   False  False   False
# 2         False  False   False   False    True    True    True  False   False
# 3         False  False   False   False   False   False   False  False   False
# 4         False  False   False   False   False   False   False  False   False
# ..          ...    ...     ...     ...     ...     ...     ...    ...     ...
# 191       False  False    True    True   False    True    True  False    True
# 192       False  False   False   False    True    True    True  False   False
# 193       False  False   False   False    True   False    True  False   False
# 194       False  False   False   False    True    True    True  False   False
# 195       False  False   False   False    True   False    True  False   False
#
#      2016.2  ...  2001.2  2001.3  2001.4  2001.5   2000  2000.1  2000.2  \
# 0     False  ...   False   False   False   False  False   False   False
# 1     False  ...   False   False   False   False  False   False   False
# 2     False  ...   False    True    True    True  False   False   False
# 3     False  ...   False   False   False   False  False   False   False
# 4     False  ...   False   False   False   False  False   False   False
# ..      ...  ...     ...     ...     ...     ...    ...     ...     ...
# 191    True  ...    True    True    True    True   True    True    True
# 192   False  ...   False    True    True    True  False   False   False
# 193   False  ...   False    True   False    True  False   False   False
# 194   False  ...   False    True    True    True  False   False   False
# 195   False  ...   False    True   False    True  False   False   False
#
#      2000.3  2000.4  2000.5
# 0     False   False   False
# 1     False   False   False
# 2      True    True    True
# 3     False   False   False
# 4     False   False   False
# ..      ...     ...     ...
# 191    True    True    True
# 192    True    True    True
# 193    True   False    True
# 194    True    True    True
# 195    True   False    True
#
# [196 rows x 109 columns]

# %% [markdown]
# ##### **Del processo di esportazione non si ha informazioni, durante tale operazione possono venire a mancare alcuni dati che si sono cancellati o persi**

# %% [markdown]
# E' opportuno ragionare sia sui dati mancanti autodescrittivi, che sono evidenti ed espliciti, sia sul fatto che il risultato finale dell'analisi possibilmente sarà influenzato dai dati mancanti.
#
# **NAN (not a number)** è il tipo di dato mancante introdotto da Python specifico per i numeri, diverso da **NONE** (codifica generica per tutti i dati)
#
# Non fare un'accurata analisi dei dati mancanti è un errore dal punto di vista metodologico

# %% [markdown]
# ***Quale conseguenze in presenza di NAN?***
#
# è possibile procedere in due modi:
#
# -sostituendo in modo esplicito Nan con 0 (np.nansum fa la somma interpretando NAN come 0), oppure con altri valori specificati (data.fillna(0));
#
# -eliminando il valore mancante (dropna( )).
#
# Cancellare l'intera riga o il 50% delle righe non porta ad avere efficaci risultati, perchè si eliminerebbero dati che per una variabile sono mancanti ma per altre no.

# %% [markdown]
# #### Dunque sarebbe opportuno filtrare tutte le righe che restituiscono il valore booleano FALSE in un'unica colonna.

# %%
df_sanitation.loc[(df_sanitation['2017'] == 'False')]  # non restituisce nulla perché per le stringhe bisogna utilizzare un'altra funzione
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 2017, 2017.1, 2017.2, 2017.3, 2017.4, 2017.5, 2016, 2016.1, 2016.2, 2016.3, 2016.4, 2016.5, 2015, 2015.1, 2015.2, 2015.3, 2015.4, 2015.5, 2014, 2014.1, 2014.2, 2014.3, 2014.4, 2014.5, 2013, 2013.1, 2013.2, 2013.3, 2013.4, 2013.5, 2012, 2012.1, 2012.2, 2012.3, 2012.4, 2012.5, 2011, 2011.1, 2011.2, 2011.3, 2011.4, 2011.5, 2010, 2010.1, 2010.2, 2010.3, 2010.4, 2010.5, 2009, 2009.1, 2009.2, 2009.3, 2009.4, 2009.5, 2008, 2008.1, 2008.2, 2008.3, 2008.4, 2008.5, 2007, 2007.1, 2007.2, 2007.3, 2007.4, 2007.5, 2006, 2006.1, 2006.2, 2006.3, 2006.4, 2006.5, 2005, 2005.1, 2005.2, 2005.3, 2005.4, 2005.5, 2004, 2004.1, 2004.2, 2004.3, 2004.4, 2004.5, 2003, 2003.1, 2003.2, 2003.3, 2003.4, 2003.5, 2002, 2002.1, 2002.2, 2002.3, 2002.4, 2002.5, 2001, 2001.1, 2001.2, ...]
# Index: []
#
# [0 rows x 109 columns]

# %%
# per le stringhe si utilizza match o contains
df_sanitation['2017'].str.match('False')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 191    False
# 192    False
# 193    False
# 194    False
# 195    False
# Name: 2017, Length: 196, dtype: object

# %%
df_sanitation['2016'].str.match('False')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 191    False
# 192    False
# 193    False
# 194    False
# 195    False
# Name: 2016, Length: 196, dtype: object

# %%
df_sanitation['2000'].str.match('False')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 191      NaN
# 192    False
# 193    False
# 194    False
# 195    False
# Name: 2000, Length: 196, dtype: object

# %%
df_sanitation.dropna(how = 'all')  # oppure visualizzazione finale del dataset eliminando le righe che contengono solo valori NaN
df_sanitation
# Out:
#                              Unnamed: 0  \
# 0                                   NaN
# 1                               Country
# 2                           Afghanistan
# 3                               Albania
# 4                               Algeria
# ..                                  ...
# 191  Venezuela (Bolivarian Republic of)
# 192                            Viet Nam
# 193                               Yemen
# 194                              Zambia
# 195                            Zimbabwe
#
#                                                   2017  \
# 0     Population using at least basic sanitation se...
# 1                                                Total
# 2                                                   43
# 3                                                   98
# 4                                                   88
# ..                                                 ...
# 191                                                 94
# 192                                                 84
# 193                                                 59
# 194                                                 26
# 195                                                 36
#
#                                                 2017.1  \
# 0     Population using at least basic sanitation se...
# 1                                                Urban
# 2                                                   62
# 3                                                   98
# 4                                                   90
# ..                                                 ...
# 191                                                NaN
# 192                                                 94
# 193                                                 88
# 194                                                 36
# 195                                                 46
#
#                                                 2017.2  \
# 0     Population using at least basic sanitation se...
# 1                                                Rural
# 2                                                   37
# 3                                                   97
# 4                                                   82
# ..                                                 ...
# 191                                                NaN
# 192                                                 78
# 193                                                 43
# 194                                                 19
# 195                                                 31
#
#                                                 2017.3  \
# 0     Population using safely managed sanitation se...
# 1                                                Total
# 2                                                  NaN
# 3                                                   40
# 4                                                   18
# ..                                                 ...
# 191                                                 24
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                 2017.4  \
# 0     Population using safely managed sanitation se...
# 1                                                Urban
# 2                                                  NaN
# 3                                                   40
# 4                                                   16
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                 67
# 194                                                NaN
# 195                                                 16
#
#                                                 2017.5  \
# 0     Population using safely managed sanitation se...
# 1                                                Rural
# 2                                                  NaN
# 3                                                   39
# 4                                                   21
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                   2016  \
# 0     Population using at least basic sanitation se...
# 1                                                Total
# 2                                                   42
# 3                                                   98
# 4                                                   88
# ..                                                 ...
# 191                                                 94
# 192                                                 82
# 193                                                 59
# 194                                                 26
# 195                                                 37
#
#                                                 2016.1  \
# 0     Population using at least basic sanitation se...
# 1                                                Urban
# 2                                                   60
# 3                                                   98
# 4                                                   90
# ..                                                 ...
# 191                                                NaN
# 192                                                 94
# 193                                                 88
# 194                                                 36
# 195                                                 48
#
#                                                 2016.2  ...  \
# 0     Population using at least basic sanitation se...  ...
# 1                                                Rural  ...
# 2                                                   36  ...
# 3                                                   97  ...
# 4                                                   82  ...
# ..                                                 ...  ...
# 191                                                NaN  ...
# 192                                                 76  ...
# 193                                                 43  ...
# 194                                                 19  ...
# 195                                                 32  ...
#
#                                                 2001.2  \
# 0     Population using at least basic sanitation se...
# 1                                                Rural
# 2                                                   22
# 3                                                   83
# 4                                                   73
# ..                                                 ...
# 191                                                NaN
# 192                                                 45
# 193                                                 27
# 194                                                 12
# 195                                                 36
#
#                                                 2001.3  \
# 0     Population using safely managed sanitation se...
# 1                                                Total
# 2                                                  NaN
# 3                                                   38
# 4                                                   19
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                 2001.4  \
# 0     Population using safely managed sanitation se...
# 1                                                Urban
# 2                                                  NaN
# 3                                                   40
# 4                                                   18
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                 67
# 194                                                NaN
# 195                                                 23
#
#                                                 2001.5  \
# 0     Population using safely managed sanitation se...
# 1                                                Rural
# 2                                                  NaN
# 3                                                   37
# 4                                                   19
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                   2000  \
# 0     Population using at least basic sanitation se...
# 1                                                Total
# 2                                                   24
# 3                                                   88
# 4                                                   84
# ..                                                 ...
# 191                                                NaN
# 192                                                 52
# 193                                                 42
# 194                                                 24
# 195                                                 46
#
#                                                 2000.1  \
# 0     Population using at least basic sanitation se...
# 1                                                Urban
# 2                                                   30
# 3                                                   97
# 4                                                   91
# ..                                                 ...
# 191                                                NaN
# 192                                                 81
# 193                                                 86
# 194                                                 46
# 195                                                 65
#
#                                                 2000.2  \
# 0     Population using at least basic sanitation se...
# 1                                                Rural
# 2                                                   22
# 3                                                   82
# 4                                                   72
# ..                                                 ...
# 191                                                NaN
# 192                                                 43
# 193                                                 27
# 194                                                 12
# 195                                                 36
#
#                                                 2000.3  \
# 0     Population using safely managed sanitation se...
# 1                                                Total
# 2                                                  NaN
# 3                                                   39
# 4                                                   19
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                                 2000.4  \
# 0     Population using safely managed sanitation se...
# 1                                                Urban
# 2                                                  NaN
# 3                                                   40
# 4                                                   18
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                 67
# 194                                                NaN
# 195                                                 23
#
#                                                 2000.5
# 0     Population using safely managed sanitation se...
# 1                                                Rural
# 2                                                  NaN
# 3                                                   38
# 4                                                   19
# ..                                                 ...
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
# [196 rows x 109 columns]

# %% [markdown]
# ***

# %% [markdown]
# ### **CONCATENAZIONE DI DATAFRAME**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\franc\Documents\UNIMI\COMPUTER SOCIETY\LIFEEX.csv")  # importo un altro dataframe 
df.head(20)
# Out:
#          Unnamed: 0 Unnamed: 1 Life expectancy at birth (years)  \
# 0        WHO region       Year                       Both sexes
# 1            Global       2016                             72.0
# 2            Global       2015                             71.7
# 3            Global       2010                             70.1
# 4            Global       2005                             68.2
# 5            Global       2000                             66.5
# 6            Africa       2016                             61.2
# 7            Africa       2015                             60.7
# 8            Africa       2010                             57.6
# 9            Africa       2005                             53.4
# 10           Africa       2000                             50.8
# 11         Americas       2016                             76.8
# 12         Americas       2015                             76.6
# 13         Americas       2010                             75.3
# 14         Americas       2005                             74.9
# 15         Americas       2000                             73.6
# 16  South-East Asia       2016                             69.5
# 17  South-East Asia       2015                             69.2
# 18  South-East Asia       2010                             67.4
# 19  South-East Asia       2005                             65.4
#
#    Life expectancy at birth (years).1 Life expectancy at birth (years).2  \
# 0                                Male                             Female
# 1                                69.8                               74.2
# 2                                69.5                               73.9
# 3                                68.0                               72.3
# 4                                66.1                               70.3
# 5                                64.4                               68.7
# 6                                59.6                               62.7
# 7                                59.1                               62.2
# 8                                56.4                               58.8
# 9                                52.3                               54.4
# 10                               49.6                               52.1
# 11                               73.8                               79.8
# 12                               73.7                               79.6
# 13                               72.3                               78.4
# 14                               71.9                               77.9
# 15                               70.4                               76.8
# 16                               67.9                               71.3
# 17                               67.6                               70.9
# 18                               66.1                               68.7
# 19                               64.4                               66.4
#
#    Life expectancy at age 60 (years) Life expectancy at age 60 (years).1  \
# 0                         Both sexes                                Male
# 1                               20.5                                19.0
# 2                               20.4                                18.9
# 3                               19.9                                18.4
# 4                               19.3                                17.8
# 5                               18.8                                17.2
# 6                               16.6                                15.9
# 7                               16.6                                15.8
# 8                               16.1                                15.4
# 9                               15.4                                14.7
# 10                              15.0                                14.3
# 11                              22.7                                21.1
# 12                              22.6                                21.0
# 13                              22.1                                20.4
# 14                              21.5                                19.8
# 15                              20.9                                19.1
# 16                              18.2                                17.2
# 17                              18.1                                17.1
# 18                              17.6                                16.7
# 19                              17.0                                16.2
#
#    Life expectancy at age 60 (years).2  \
# 0                               Female
# 1                                 21.9
# 2                                 21.8
# 3                                 21.3
# 4                                 20.7
# 5                                 20.2
# 6                                 17.3
# 7                                 17.3
# 8                                 16.7
# 9                                 16.1
# 10                                15.6
# 11                                24.3
# 12                                24.1
# 13                                23.6
# 14                                23.1
# 15                                22.5
# 16                                19.1
# 17                                19.0
# 18                                18.4
# 19                                17.8
#
#    Healthy life expectancy (HALE) at birth (years)  \
# 0                                       Both sexes
# 1                                             63.3
# 2                                             63.0
# 3                                             61.7
# 4                                             60.0
# 5                                             58.5
# 6                                             53.8
# 7                                             53.3
# 8                                             50.4
# 9                                             46.7
# 10                                            44.4
# 11                                            67.5
# 12                                            67.4
# 13                                            66.3
# 14                                            66.0
# 15                                            64.9
# 16                                            60.4
# 17                                            60.0
# 18                                            58.5
# 19                                            56.6
#
#    Healthy life expectancy (HALE) at birth (years).1  \
# 0                                               Male
# 1                                               62.0
# 2                                               61.7
# 3                                               60.4
# 4                                               58.7
# 5                                               57.2
# 6                                               52.6
# 7                                               52.1
# 8                                               49.6
# 9                                               46.0
# 10                                              43.5
# 11                                              65.5
# 12                                              65.3
# 13                                              64.1
# 14                                              63.8
# 15                                              62.6
# 16                                              59.5
# 17                                              59.2
# 18                                              57.9
# 19                                              56.3
#
#    Healthy life expectancy (HALE) at birth (years).2  \
# 0                                             Female
# 1                                               64.8
# 2                                               64.5
# 3                                               63.1
# 4                                               61.3
# 5                                               59.9
# 6                                               54.9
# 7                                               54.4
# 8                                               51.3
# 9                                               47.4
# 10                                              45.3
# 11                                              69.6
# 12                                              69.5
# 13                                              68.4
# 14                                              68.1
# 15                                              67.1
# 16                                              61.3
# 17                                              60.9
# 18                                              59.0
# 19                                              56.9
#
#    Healthy life expectancy (HALE) at age 60 (years)  \
# 0                                        Both sexes
# 1                                              15.8
# 2                                              15.7
# 3                                              15.3
# 4                                              14.8
# 5                                              14.3
# 6                                              12.5
# 7                                              12.4
# 8                                              12.0
# 9                                              11.4
# 10                                             11.0
# 11                                             17.6
# 12                                             17.5
# 13                                             17.0
# 14                                             16.6
# 15                                             16.2
# 16                                             13.3
# 17                                             13.2
# 18                                             12.7
# 19                                             12.2
#
#    Healthy life expectancy (HALE) at age 60 (years).1  \
# 0                                                Male
# 1                                                14.8
# 2                                                14.7
# 3                                                14.3
# 4                                                13.7
# 5                                                13.2
# 6                                                12.0
# 7                                                11.8
# 8                                                11.5
# 9                                                10.9
# 10                                               10.5
# 11                                               16.4
# 12                                               16.2
# 13                                               15.8
# 14                                               15.3
# 15                                               14.8
# 16                                               12.7
# 17                                               12.6
# 18                                               12.2
# 19                                               11.8
#
#    Healthy life expectancy (HALE) at age 60 (years).2
# 0                                              Female
# 1                                                16.8
# 2                                                16.6
# 3                                                16.2
# 4                                                15.8
# 5                                                15.4
# 6                                                13.1
# 7                                                13.0
# 8                                                12.4
# 9                                                11.8
# 10                                               11.4
# 11                                               18.7
# 12                                               18.6
# 13                                               18.2
# 14                                               17.8
# 15                                               17.4
# 16                                               13.9
# 17                                               13.7
# 18                                               13.2
# 19                                               12.7

# %% [markdown]
# * Per prima cosa faccio qualche operazione per ordinare il mio dataset

# %%
df.rename(columns={'Unnamed: 0' : 'WHO Region', 'Unnamed: 1' : 'Year'})  # per rinominare il nome della prima e seconda colonna, passo i vecchi e nuovi nomi come dizionario
# ho utilizzato la funzione rename
# Out:
#                WHO Region   Year Life expectancy at birth (years)  \
# 0              WHO region   Year                       Both sexes
# 1                  Global   2016                             72.0
# 2                  Global   2015                             71.7
# 3                  Global   2010                             70.1
# 4                  Global   2005                             68.2
# 5                  Global   2000                             66.5
# 6                  Africa   2016                             61.2
# 7                  Africa   2015                             60.7
# 8                  Africa   2010                             57.6
# 9                  Africa   2005                             53.4
# 10                 Africa   2000                             50.8
# 11               Americas   2016                             76.8
# 12               Americas   2015                             76.6
# 13               Americas   2010                             75.3
# 14               Americas   2005                             74.9
# 15               Americas   2000                             73.6
# 16        South-East Asia   2016                             69.5
# 17        South-East Asia   2015                             69.2
# 18        South-East Asia   2010                             67.4
# 19        South-East Asia   2005                             65.4
# 20        South-East Asia   2000                             63.5
# 21                 Europe   2016                             77.5
# 22                 Europe   2015                             77.2
# 23                 Europe   2010                             75.7
# 24                 Europe   2005                             73.5
# 25                 Europe   2000                             72.5
# 26  Eastern Mediterranean   2016                             69.1
# 27  Eastern Mediterranean   2015                             68.8
# 28  Eastern Mediterranean   2010                             68.1
# 29  Eastern Mediterranean   2005                             66.2
# 30  Eastern Mediterranean   2000                             65.5
# 31        Western Pacific   2016                             76.9
# 32        Western Pacific   2015                             76.7
# 33        Western Pacific   2010                             75.8
# 34        Western Pacific   2005                             74.7
# 35        Western Pacific   2000                             72.8
#
#    Life expectancy at birth (years).1 Life expectancy at birth (years).2  \
# 0                                Male                             Female
# 1                                69.8                               74.2
# 2                                69.5                               73.9
# 3                                68.0                               72.3
# 4                                66.1                               70.3
# 5                                64.4                               68.7
# 6                                59.6                               62.7
# 7                                59.1                               62.2
# 8                                56.4                               58.8
# 9                                52.3                               54.4
# 10                               49.6                               52.1
# 11                               73.8                               79.8
# 12                               73.7                               79.6
# 13                               72.3                               78.4
# 14                               71.9                               77.9
# 15                               70.4                               76.8
# 16                               67.9                               71.3
# 17                               67.6                               70.9
# 18                               66.1                               68.7
# 19                               64.4                               66.4
# 20                               62.5                               64.4
# 21                               74.2                               80.8
# 22                               73.8                               80.5
# 23                               72.0                               79.3
# 24                               69.5                               77.6
# 25                               68.4                               76.7
# 26                               67.7                               70.7
# 27                               67.4                               70.4
# 28                               66.7                               69.5
# 29                               64.8                               67.8
# 30                               64.2                               66.9
# 31                               75.0                               78.9
# 32                               74.8                               78.8
# 33                               73.8                               77.9
# 34                               72.7                               76.8
# 35                               70.8                               75.0
#
#    Life expectancy at age 60 (years) Life expectancy at age 60 (years).1  \
# 0                         Both sexes                                Male
# 1                               20.5                                19.0
# 2                               20.4                                18.9
# 3                               19.9                                18.4
# 4                               19.3                                17.8
# 5                               18.8                                17.2
# 6                               16.6                                15.9
# 7                               16.6                                15.8
# 8                               16.1                                15.4
# 9                               15.4                                14.7
# 10                              15.0                                14.3
# 11                              22.7                                21.1
# 12                              22.6                                21.0
# 13                              22.1                                20.4
# 14                              21.5                                19.8
# 15                              20.9                                19.1
# 16                              18.2                                17.2
# 17                              18.1                                17.1
# 18                              17.6                                16.7
# 19                              17.0                                16.2
# 20                              16.7                                15.8
# 21                              22.3                                20.2
# 22                              22.1                                20.0
# 23                              21.4                                19.2
# 24                              20.3                                18.1
# 25                              19.7                                17.3
# 26                              18.2                                17.5
# 27                              18.1                                17.4
# 28                              18.0                                17.3
# 29                              17.6                                16.9
# 30                              17.5                                16.8
# 31                              21.0                                19.5
# 32                              20.9                                19.4
# 33                              20.5                                19.0
# 34                              20.1                                18.6
# 35                              19.3                                17.8
#
#    Life expectancy at age 60 (years).2  \
# 0                               Female
# 1                                 21.9
# 2                                 21.8
# 3                                 21.3
# 4                                 20.7
# 5                                 20.2
# 6                                 17.3
# 7                                 17.3
# 8                                 16.7
# 9                                 16.1
# 10                                15.6
# 11                                24.3
# 12                                24.1
# 13                                23.6
# 14                                23.1
# 15                                22.5
# 16                                19.1
# 17                                19.0
# 18                                18.4
# 19                                17.8
# 20                                17.5
# 21                                24.1
# 22                                23.9
# 23                                23.2
# 24                                22.3
# 25                                21.6
# 26                                19.0
# 27                                18.8
# 28                                18.7
# 29                                18.4
# 30                                18.2
# 31                                22.5
# 32                                22.4
# 33                                22.1
# 34                                21.6
# 35                                20.9
#
#    Healthy life expectancy (HALE) at birth (years)  \
# 0                                       Both sexes
# 1                                             63.3
# 2                                             63.0
# 3                                             61.7
# 4                                             60.0
# 5                                             58.5
# 6                                             53.8
# 7                                             53.3
# 8                                             50.4
# 9                                             46.7
# 10                                            44.4
# 11                                            67.5
# 12                                            67.4
# 13                                            66.3
# 14                                            66.0
# 15                                            64.9
# 16                                            60.4
# 17                                            60.0
# 18                                            58.5
# 19                                            56.6
# 20                                            54.8
# 21                                            68.4
# 22                                            68.1
# 23                                            66.9
# 24                                            65.1
# 25                                            64.2
# 26                                            59.7
# 27                                            59.4
# 28                                            58.6
# 29                                            57.0
# 30                                            56.2
# 31                                            68.9
# 32                                            68.6
# 33                                            67.8
# 34                                            66.9
# 35                                            65.2
#
#    Healthy life expectancy (HALE) at birth (years).1  \
# 0                                               Male
# 1                                               62.0
# 2                                               61.7
# 3                                               60.4
# 4                                               58.7
# 5                                               57.2
# 6                                               52.6
# 7                                               52.1
# 8                                               49.6
# 9                                               46.0
# 10                                              43.5
# 11                                              65.5
# 12                                              65.3
# 13                                              64.1
# 14                                              63.8
# 15                                              62.6
# 16                                              59.5
# 17                                              59.2
# 18                                              57.9
# 19                                              56.3
# 20                                              54.5
# 21                                              66.1
# 22                                              65.7
# 23                                              64.3
# 24                                              62.2
# 25                                              61.2
# 26                                              59.1
# 27                                              58.8
# 28                                              58.1
# 29                                              56.4
# 30                                              55.8
# 31                                              67.7
# 32                                              67.5
# 33                                              66.7
# 34                                              65.7
# 35                                              64.0
#
#    Healthy life expectancy (HALE) at birth (years).2  \
# 0                                             Female
# 1                                               64.8
# 2                                               64.5
# 3                                               63.1
# 4                                               61.3
# 5                                               59.9
# 6                                               54.9
# 7                                               54.4
# 8                                               51.3
# 9                                               47.4
# 10                                              45.3
# 11                                              69.6
# 12                                              69.5
# 13                                              68.4
# 14                                              68.1
# 15                                              67.1
# 16                                              61.3
# 17                                              60.9
# 18                                              59.0
# 19                                              56.9
# 20                                              55.1
# 21                                              70.7
# 22                                              70.5
# 23                                              69.5
# 24                                              68.2
# 25                                              67.3
# 26                                              60.4
# 27                                              60.1
# 28                                              59.2
# 29                                              57.6
# 30                                              56.8
# 31                                              70.0
# 32                                              69.8
# 33                                              69.1
# 34                                              68.1
# 35                                              66.5
#
#    Healthy life expectancy (HALE) at age 60 (years)  \
# 0                                        Both sexes
# 1                                              15.8
# 2                                              15.7
# 3                                              15.3
# 4                                              14.8
# 5                                              14.3
# 6                                              12.5
# 7                                              12.4
# 8                                              12.0
# 9                                              11.4
# 10                                             11.0
# 11                                             17.6
# 12                                             17.5
# 13                                             17.0
# 14                                             16.6
# 15                                             16.2
# 16                                             13.3
# 17                                             13.2
# 18                                             12.7
# 19                                             12.2
# 20                                             11.9
# 21                                             17.4
# 22                                             17.2
# 23                                             16.7
# 24                                             15.8
# 25                                             15.3
# 26                                             13.3
# 27                                             13.2
# 28                                             13.0
# 29                                             12.6
# 30                                             12.4
# 31                                             16.6
# 32                                             16.5
# 33                                             16.2
# 34                                             15.9
# 35                                             15.3
#
#    Healthy life expectancy (HALE) at age 60 (years).1  \
# 0                                                Male
# 1                                                14.8
# 2                                                14.7
# 3                                                14.3
# 4                                                13.7
# 5                                                13.2
# 6                                                12.0
# 7                                                11.8
# 8                                                11.5
# 9                                                10.9
# 10                                               10.5
# 11                                               16.4
# 12                                               16.2
# 13                                               15.8
# 14                                               15.3
# 15                                               14.8
# 16                                               12.7
# 17                                               12.6
# 18                                               12.2
# 19                                               11.8
# 20                                               11.4
# 21                                               15.9
# 22                                               15.7
# 23                                               15.1
# 24                                               14.2
# 25                                               13.5
# 26                                               13.0
# 27                                               12.9
# 28                                               12.7
# 29                                               12.3
# 30                                               12.1
# 31                                               15.6
# 32                                               15.5
# 33                                               15.1
# 34                                               14.8
# 35                                               14.2
#
#    Healthy life expectancy (HALE) at age 60 (years).2
# 0                                              Female
# 1                                                16.8
# 2                                                16.6
# 3                                                16.2
# 4                                                15.8
# 5                                                15.4
# 6                                                13.1
# 7                                                13.0
# 8                                                12.4
# 9                                                11.8
# 10                                               11.4
# 11                                               18.7
# 12                                               18.6
# 13                                               18.2
# 14                                               17.8
# 15                                               17.4
# 16                                               13.9
# 17                                               13.7
# 18                                               13.2
# 19                                               12.7
# 20                                               12.4
# 21                                               18.7
# 22                                               18.5
# 23                                               18.0
# 24                                               17.3
# 25                                               16.7
# 26                                               13.6
# 27                                               13.5
# 28                                               13.3
# 29                                               12.9
# 30                                               12.7
# 31                                               17.6
# 32                                               17.5
# 33                                               17.3
# 34                                               16.9
# 35                                               16.3

# %%
Gender = ["Male", "Female", "Both sexes"]

# %%
df["Gender"] = Gender  # volevo creare una nuova colonna Gender con le tre modalità da aggiungere al dataframe e poi eliminare la riga di indice 0, ma l'operazione non è quella giusta...
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-b331774bf447> in <module>
# ----> 1 df["Gender"] = Gender  # volevo creare una nuova colonna Gender con le tre modalità da aggiungere al dataframe e poi eliminare la riga di indice 0, ma l'operazione non è quella giusta...
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# -> 3636             value = sanitize_index(value, self.index, copy=False)
#    3637             if not isinstance(value, (np.ndarray, Index)):
#    3638                 if isinstance(value, list) and len(value) > 0:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     609
#     610     if len(data) != len(index):
# --> 611         raise ValueError("Length of values does not match length of index")
#     612
#     613     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index
